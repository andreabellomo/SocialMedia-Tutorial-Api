# %%
from googleapiclient.discovery import build
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure as fg

# %%
api_key = "AIzaSyDQjmhO9zDk1bQEjtEmIKQu6BbJWSfAU9M"
youtube = build('youtube', 'v3', developerKey=api_key)
channel_ids = ['UC5yXB_ThsufRJYMRlzIGoeQ', # Galeazzi
               'UCs_ouz-Hdk1vQRofWi3JkDg', # TechPrincess 
               'UCdufkvMrmyR1TMhDG8PhsJw', # HDblog
               'UCfzijU5thstIWeAQI4a-jag', # TuttoAndroid
               'UC-OXGAb_1cee868asQIcgqw', # iPhoneItalia
               'UC1jqQ11rUZe70O1j9XDk_Rw'
              ]

# %%
def get_channels_details (youtube, channels_ids):
    all_data = []
    request = youtube.channels().list(part='snippet,contentDetails,statistics',
                                      id = ','.join(channel_ids)).execute();
    
    for i in range(len(request['items'])):
        data = dict(Channel_name =  request['items'][i]['snippet']['title'],
                    Subscribers =  request['items'][i]['statistics']['subscriberCount'],
                    Views =  request['items'][i]['statistics']['viewCount'],
                    Total_videos =  request['items'][i]['statistics']['videoCount'],
                    playlist_all_video_id =  request['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
                                    
    return all_data

# %%
get_channels_details(youtube, channel_ids)
get_channels_details(youtube, channel_ids)
# Out:
# [{'Channel_name': "√ ̅ ̅ν̅ι̅ѕ̅н̅ι̅υ̅ѕ̅¹̅⁷̅ ̅ ➜ L'informatica papale papale",
#   'Subscribers': '24100',
#   'Views': '4265329',
#   'Total_videos': '550',
#   'playlist_all_video_id': 'UU1jqQ11rUZe70O1j9XDk_Rw'}]

# %%
dataframe = pd.DataFrame(get_channels_details(youtube, channel_ids))
#dataframe.dtypes
dataframe
# Out:
#                                         Channel_name Subscribers    Views  \
# 0  √ ̅ ̅ν̅ι̅ѕ̅н̅ι̅υ̅ѕ̅¹̅⁷̅ ̅ ➜ L'informatica papa...       24100  4265329
#
#   Total_videos     playlist_all_video_id
# 0          550  UU1jqQ11rUZe70O1j9XDk_Rw

# %%
dataframe['Views'] = dataframe.Views.astype(int)
dataframe['Subscribers'] = dataframe.Subscribers.astype(int)
dataframe['Total_videos'] = dataframe.Total_videos.astype(int)
#dataframe.dtypes

dataframe.plot(x = 'Channel_name', y = 'Views', kind = 'bar' )
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.show()

# %%
dataframe.plot(x = 'Channel_name', y = 'Total_videos', kind = 'bar' )
plt.show()

# %%
dataframe.plot(x = 'Channel_name', y = 'Subscribers', kind = 'bar' )
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.show()

# %%
playlist_id = dataframe.iloc[0]['playlist_all_video_id']
playlist_id
# Out:
# 'UU1jqQ11rUZe70O1j9XDk_Rw'

# %%
def get_video_ids(youtube, playlist_id):
    
    req = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50).execute()
    
    video_ids = []
    for i in range(len(req['items'])):
        video_ids.append(req['items'][i]['contentDetails']['videoId'])
        
    token_page = req.get('nextPageToken')
    flag = True
    
    while flag:
        if token_page is None:
            flag = False
        else:
            req = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = token_page).execute();
            
            for i in range(len(req['items'])):
                video_ids.append(req['items'][i]['contentDetails']['videoId'])
            
            token_page = req.get('nextPageToken')
        
    return video_ids

# %%
get_video_ids(youtube,'UUs_ouz-Hdk1vQRofWi3JkDg')
# Out:
# ['XBMWHXiI1yo',
#  'QJ_84ePOdYc',
#  'XxwOQbsEs08',
#  'iEuYNTR93RU',
#  'antuVBgNPGY',
#  'XpsDmr8afeI',
#  'AtRqXsGGjuE',
#  'V5ifug23HxU',
#  'Dt59d046ixw',
#  'z2fkG-Jf60c',
#  'UChmMZ6Av1M',
#  'BPgo9ptdXjc',
#  'UcKbbJ8A_8g',
#  'bviFsGb3rpc',
#  'REfJzJNLv-k',
#  'espQ5_Lasyk',
#  'xtAjIR7tqnQ',
#  'oxEoF5qofDE',
#  '8VZeneLqS_4',
#  'Y-y6x5wvFA8',
#  '3qkaSzCYxv4',
#  '1_3jiV3dDNY',
#  '5u53bmhOliI',
#  'IqSc7Lyr90Y',
#  'JhPiVQa1LIU',
#  'lccZ_NiySgw',
#  'kzFXYrV1IDU',
#  'V5q0LaAr6w8',
#  'yud8te53rsY',
#  'WUf0JARVQ3M',
#  'dSF5FEn6BKE',
#  'fCkXd4kbla0',
#  'bGVEc4h04uA',
#  '56FE37BgBFA',
#  'UMATJW7Vnko',
#  'mUZ7r4ZqoLY',
#  'bpFRq9kWkWs',
#  'NeajLLY7jf0',
#  '--vhlNtf4lU',
#  'j0rDJCCTyMs',
#  '54oGc-lap8c',
#  'VoryG_UeFgc',
#  'PrD9GgHbUVE',
#  'QbsxDj9SLkc',
#  'tM5azd9hycE',
#  'HNFe2Us2i3Y',
#  'ZkJGrhtvUig',
#  'g_CjVu8CEcA',
#  'l3Ho0MjREYc',
#  'MsqktLYQaNI',
#  'bJYP6_1qCD4',
#  'ULx1LPL4Az0',
#  'x7ABwW4AFPw',
#  'OR2mt10sZ0o',
#  'JONm4eHMp_A',
#  '_T2NWYA13Ec',
#  'QJcgTUwCOGE',
#  'OtqVWSSs-RY',
#  '5MuLSOxp60s',
#  'YNPRO8zTCFw',
#  '_jSEza_2Tps',
#  'wMOoPDTLp8s',
#  '7pwqMUtp06o',
#  'wCTyD-MywyE',
#  'VnMHuwlySN0',
#  'sWYfp95hiCQ',
#  'AXFQo0q3aVQ',
#  'rSgOq63D3Y0',
#  'uWUU3mfDIOM',
#  'htxZ5Sr79eg',
#  '2tA6QyUNlb8',
#  'lH9_k9MeM20',
#  'y3nx6qvlHY4',
#  'h-4taxvk6PY',
#  'u4__9N2BKfs',
#  '5cAicPx29N8',
#  'UPm7_ljUrbM',
#  'TMeGLT4JF7Y',
#  'qedv_yXN5u4',
#  '323jMjO0KuA',
#  'J57MsItyhKw',
#  'fU1T33uhS_c',
#  '-_uKWDwQQLU',
#  '49aiirGwxBY',
#  'g8VAKx8OBQM',
#  '2SKIo02CpDA',
#  'GpHyZBnsoPI',
#  'TlRpOLGNIr4',
#  'sAFRhgeKUZw',
#  'MTmQfr56XvQ',
#  'PYWA9v1PkQQ',
#  'ecUd44qSPk4',
#  'BuxtkUGeDEw',
#  '8BZpJgYYyJg',
#  'fHq46kOiS-I',
#  'atOV2PggH1g',
#  'MoxT5aCT3GQ',
#  'LuatoeUMXmI',
#  'JTTb_3WFp-k',
#  'zsPQ-EB7dAw',
#  'I-HuVj-3eYU',
#  'o3BL5UqkV58',
#  'JhnDHhYZ_dk',
#  '-uQXzitu3uU',
#  'qfAba3aAYZA',
#  'lN1_jQcfaXs',
#  '2g3gCJ98gWs',
#  'sm6lNq60ET4',
#  'ooCqbqZO35c',
#  'nMbbUp0ajV8',
#  '4pNQiq7Coz4',
#  'TXPct4cLk7E',
#  'P9uJiJiuPhA',
#  'mUNOVpE0GUs',
#  'fmqq81fCPZA',
#  'JjPg_0U05oE',
#  'QlAmRKUqDOs',
#  'eq4ZFFH_WsU',
#  '5wj0sLqFP7E',
#  'Me5Gf5NcE0M',
#  'q3h_7PYRlQs',
#  'wc__ZNYoV8Q',
#  'XrSCi78A7JA',
#  'b9GO1O5FMwg',
#  'AKNM6lqbGQc',
#  '-QdRe_64yTE',
#  'TCSVy2nf_Bc',
#  'vM0a6koTMno',
#  'bPtNR-YdXTA',
#  'b8YHkZl2kmk',
#  'nqIkj-8a5KY',
#  'gd_e0oHglBc',
#  '5GHi7ry_2bE',
#  'in0yuzCdYac',
#  'HfEHCif1fA0',
#  'wixTbcseKug',
#  'EJJOIxl6zVE',
#  'Ug84gQNMFiM',
#  'WUAojhQA3LE',
#  'zFZsTT2ruow',
#  'drD9BDNjIWQ',
#  'K2cRV9VA8CU',
#  'YEGpkfL0OYA',
#  'kInaNN6ySOA',
#  'wBsvgDyNQc4',
#  'iK33zngrEBE',
#  'di8m_HUzlLg',
#  'kgkP11vTY_I',
#  'sIEYetTdtQY',
#  'r2BZqAgUpUM',
#  '8yPYnVBIEmY',
#  'kBkRMl1XHGw',
#  'PH98qKaUueg',
#  'FdCRoLGoaPQ',
#  '5-8TB_TZfGY',
#  'rt-0N_ucN9w',
#  'o2CS9JCuVkg',
#  'uEue37ULhHM',
#  '9GO3_msIqAs',
#  'qoAee2lnFkE',
#  'I6qn8zvOjFQ',
#  'v9DMVkeyTYE',
#  'X6e011C9J-E',
#  '1Zk9n_Iy9wA',
#  'fUfP-AHQ-jc',
#  'FblqLKuZeu8',
#  '4f3EEXnRSrw',
#  'KL3CWCooGn8',
#  'ZtfCL1fJrwA',
#  'W1SHxCkyDpM',
#  '4AXH0ZOi7DA',
#  'nJso-VVURCs',
#  'qp7po3qjrRY',
#  '0Gus7iFWgoQ',
#  'NysNX_PV3A0',
#  'HC-qDnStM84',
#  '9_tasuax_90',
#  'wCRuko6dc0I',
#  'dsilOXp0i5c',
#  'llxwX2Y6rVs',
#  'klB1QHKNBgw',
#  'S29cxbBmazw',
#  '2PKuFaTOZQs',
#  'J_NfS_Y-nAw',
#  'p7dOHGG0qsc',
#  'tHRdWLlPE_I',
#  'MLESqyKx3dk',
#  '_dcI7uJudI0',
#  'JtxmLCMwick',
#  'y7zy26FGvjI',
#  'bLMjxbT6trs',
#  'gO_407xRWPU',
#  'hzWfjUX6kXY',
#  'NfzdOGDpmpA',
#  'bvGwDOSpeAY',
#  'ShjJcJQbtZA',
#  'wHV3BFlo1qQ',
#  'Pdw9Z-5-feM',
#  'CJY80PxmiNs',
#  'sfoHJszOlvI',
#  '_mIlV4EWkvw',
#  'AN-6hiUAgS8',
#  '-cgjzN28JKo',
#  'jTUvnwhvDvM',
#  'feWZGlfyZJc',
#  '1gFZ0FMWYHY',
#  'DgtenJVbm8s',
#  '88SYmEnWyLk',
#  '48xNVlRlD5g',
#  '9q-h4-rvyZ0',
#  'jPcieD3JlBY',
#  'yGPGctZDOs8',
#  'KYO7rszQ-78',
#  'Zb5wFE5D3sw',
#  'kM9TxavRAv4',
#  'zoFYm8zUtFE',
#  'lIWQ5gckchs',
#  'dYkT3p9BXPk',
#  'hjiRYuOT4AU',
#  'ywwpx1ha1So',
#  'h6nGx6Js0qg',
#  'JwWtMZHR1jI',
#  'AnhDaMeNefg',
#  'zLygDcTjARA',
#  'tcyiaD-IWqk',
#  'Kulh49RpfyY',
#  'pf8g5U6sA6s',
#  'qdpCSzMdyFY',
#  'oOVh4zyYQV0',
#  'ieAGfOz0VPk',
#  'c1-cySbQtR8',
#  '4FOgCVcCcHE',
#  '78DVyzY-YsU',
#  '64azoAbnXaw',
#  'Yz80oBfFXuI',
#  'UNBp9CcH_C4',
#  'PO0yr4UtrTI',
#  'xgC6fWZZ1X0',
#  'dn_oK3asF4k',
#  'W-7ANxylzG4',
#  'EG4dbQUN-fM',
#  'h4ZufOuSlm0',
#  'f1RUeya1Y9I',
#  'JEN4mf2t0Bo',
#  'NNe0YmhZ_Co',
#  'Dx4S5sScV0I',
#  'xyrAaHkoJTY',
#  'lECMVyQuoZU',
#  'JqNI0B_izeY',
#  'c2sNPk8v4CM',
#  '9OXWL11qaiU',
#  'PsNC2KxozfQ',
#  'MyNrx_yODMU',
#  'NHbRiFPo8AM',
#  'EKyITFqBUN4',
#  'J1iqMYl8NM0',
#  'gU5hRCAHAMg',
#  'Ymnrch_sTTA',
#  'hVcQfYQy4eM',
#  'LzpPRwJE_gQ',
#  'Ok5qlNaZ2lU',
#  'mbAS5_dZ56Y',
#  '1JhXVfMR58Y',
#  'Ote5j_tuGYI',
#  'Z0n3540nM1M',
#  '8KJ3Zd35G48',
#  '_srXoCUO5xg',
#  'XRwzXuKVA1w',
#  '3n5ncxUuoh8',
#  'YpX1qIiDs58',
#  'BFFG_Zy7dJk',
#  'C87eoMQfUJM',
#  'bs5h9MmelXY',
#  'dc6T_H4kb8k',
#  'leiGe8S1GIY',
#  'tiadOBe_g0g',
#  'eicnkKpfNT4',
#  'H4DXMZHhN9E',
#  'sfJGRqnTIkU',
#  '8S11JBISJ3w',
#  'X26fOpFOPXc',
#  'Yd6cASQmQyY',
#  'jvDF52t-M-0',
#  '4gxnH2ouzP8',
#  'pqd3WDnQiqM',
#  'ib77zwLlQnA',
#  'ew-GGKHYyrk',
#  'nhs_ex6-vJs',
#  'RzTN8qBhwqA',
#  '4VRQFlT8ur0',
#  'ruz2mN9SuQs',
#  'BucMKoPD6ys',
#  'svk4ab2VJBE',
#  'RiHf-H4fdHU',
#  'Fm0I9jXGpyg',
#  'EiLHCHBx9ME',
#  '34dJt4Tb1BU',
#  'Hrk_Hq8nSq0',
#  'Gix90EmSH-8',
#  'qXJwPrB6Unw',
#  'hNa8M2kD93M',
#  '76ixB24Bag8',
#  'Jy-67A79JvU',
#  'zxv1FOFtyDM',
#  'JNap8vlOu6o',
#  'AnaMFY_9awk',
#  'TMX2vyX2DYQ',
#  'voDcW3VaBuo',
#  'boJr7wulpqc',
#  'KITrfem1aBg',
#  'ZFEXSR_HtrQ',
#  'M2lP0DawvGw',
#  'A5fxTLQlNEg',
#  'v1OjsCl0MHg',
#  'y3HZQgFnE2U',
#  'gCzLN4VUhlI',
#  'bZJfXhDIDcM',
#  'CSgjt-DLHdg',
#  'eKDVYSwhRXU',
#  'LA0x5tLLAW8',
#  'O633NUN3Sv8',
#  'K7GIjvcHApI',
#  'VUraiGElZn8',
#  'mH22nwGds8U',
#  'ewGVKcSGWGo',
#  '5yQIFBwE7ls',
#  'EqKM_zwm9Qc',
#  'PeTQQXwseHk',
#  'g15x3LYUyUg',
#  'm-f0GgsOQc4',
#  'mwhcFUtIGhE',
#  'O53lf1JhpEI',
#  'REvJHR5S3io',
#  'lpEMOJBgIz8',
#  '-ofglK5vZco',
#  'ID2InOTmVFw',
#  'kGAmsJc_jEU',
#  'gwB104pfi5o',
#  'VdqU6uNDjBc',
#  'JOVfVVKnvcw',
#  'GxIaj_RSDvs',
#  'Ikw9j8COOOo',
#  'MShltpeT9iI',
#  'iW3DrBqkm30',
#  'q8O_gJo9FjU',
#  'Qu4BVQIBvcE',
#  'j5adNa5izJs',
#  'KxNdnfP-YgQ',
#  'U_UftkZW3Z8',
#  'Cii8I2z3Hhc',
#  'NKCn5ksuUnM',
#  'g5HDqeJpwjk',
#  'rsnSvX7mTeE',
#  'lMEnJQBQ4EM',
#  'l60xnT2PuR4',
#  'vSqWHOYOXI8',
#  'gTbez8ZPZlA',
#  'HrukBsx-QvM',
#  'anK4W8M1BEw',
#  'uXHIH5nAi9w',
#  'rOlHHCZive8',
#  '9A5foCQ7zmA',
#  'NCMUpfbGc6E',
#  'zYo5AXyAm9Q',
#  'pOGGbHBtlFo',
#  '9atyww96mvY',
#  'ny0IMzeD8ho',
#  'b8HWTfRztT4',
#  'J9qkuuI3e-I',
#  'PXjOFLEEHOk',
#  'DcSMAoD9ToY',
#  'tFwht4DqZck',
#  'D_wOD421ZeQ',
#  'LLbIJyC5OnE',
#  'Q7Qw9_RZy6U',
#  'w47EbrOx7Jk',
#  'MBzLYa3-jRA',
#  'IlLTDJDKL34',
#  'ML_WpH1w_cY',
#  'lGxVGn05HWw',
#  'HQMCwYaI5QU',
#  'zU4Yi2yljhk',
#  'Alq31Y3hmI4',
#  'B9396-fsVvI',
#  'hZo9Gg9ZOq4',
#  'TxPmJN0e4DU',
#  '4cKgIJXMy3Y',
#  'VMegLWr6cZE',
#  'qEhhQ_XDBpA',
#  'S1IMlBtRifk',
#  'myXEkcIxm44',
#  'ScE0ZBLvUbQ',
#  'JEmQFp_rhSQ',
#  'C226NwEspu8',
#  'Xew9OJzrcj4',
#  'M9iJZwc1S3k',
#  'ciJbMuqe8a0',
#  '-SDDiZAft4E',
#  'tveWNGTutQc',
#  'zlKyybSxSRg',
#  '1kKKknU5I0I',
#  '9E4HCaTUzf4',
#  'BlMjoh6bjhc',
#  '7khtO_Os6vA',
#  'FccV0Km8KA4',
#  'pm6f1bALY6g',
#  'f3fl98rFtAs',
#  'q8fkV38r1so',
#  'pLR6H16H4oE',
#  '49WmIzvCX3k',
#  'R9rlsP6jiOs',
#  'qG_Nc-YQj5Y',
#  'P1sZFgIi8EU',
#  'GCQDZ-PxN5s',
#  'OdILLbnBcO0',
#  'vAbNaDQe7oE',
#  'Ji6ppcR6TGM',
#  '5S5sLWbTxEs',
#  'b5Uk-XQfd4c',
#  'H9W0L4LXkJ0',
#  'QQZMsyV8sKc',
#  'iJ9yxtktkNE',
#  'HyjgYJumo6E',
#  'gEGjFZUaKTo',
#  'RHJKKpVSHfg',
#  'i9_LeLO_Gtk',
#  'OW_u_Gj8kxs',
#  'TjCWcdhfGKo',
#  'pUuCgwGpw-U',
#  'qMXA306STEQ',
#  'Dzm3oCsc094',
#  '7JT4xSXYttA',
#  'vh8_9EPkTDY',
#  'qcB41PqgIOc',
#  'FPkoRMLpA-0',
#  'H7_9V_tsk7Q',
#  'PJzEDHvnikc',
#  'TJ9dX4dE_G0',
#  'f3o1TWShNlk',
#  'g4WRHA3n4Bw',
#  'xAof3iLSL8A',
#  'RQXSnh3DkK0',
#  'pIy-ZxO7I74',
#  'YLLBlLqMkuY',
#  'wRX1REuOdIs',
#  'FxLkgjNdXt0',
#  'g1napt7HAW8',
#  'Zn8McRy3w6w',
#  'PfjJqBLqQxs',
#  '4BU9rIH8XPg',
#  'qyOSQYI5lHw',
#  'bPnKsBJ0q-k',
#  'wtlRVlVhTHw',
#  'wB095nvT8c4',
#  'ZEmW8qplk6A',
#  'YvQ65bAfIpg',
#  'kOoDyfDHFuw',
#  'mjh81ZxPyMs',
#  'nhh6JZO8-gY',
#  '_Fr62iM2N6g',
#  'Ek7147NJOuk',
#  '01X94zXW-wE',
#  '9EZrO_3T55g',
#  '2lpO17EU-wY',
#  '_LfOT-Ptcqs',
#  'YIKj1tenBrs',
#  '-Z1LXxeXdaM',
#  'tXlPYmsSmjQ',
#  'ciPyRYU7VlQ',
#  '7x9BnfWbmCs',
#  'aur09hBhr6I',
#  'IfVwrfDLHzA',
#  'm2klIR3sxdw',
#  'yl86dTV5we8',
#  'ov_hjaCjTtA',
#  'ZyV_-8vx0CQ',
#  'cXNdvjHj35U',
#  'xpiV9p_24SM',
#  'T_lSZEBJoY8',
#  '7NPvzIE7XoI',
#  'B8ItRgtA78w',
#  'MoPB2uijthE',
#  'Kv1HX7iuR0Y',
#  'e0OmVhMSL7I',
#  'jQuzFLRgHv4',
#  's1u78-Sm_CQ',
#  'C-wkeVX4KFA',
#  'sW1P0EYap1Q',
#  'TBEq4bj9CLE',
#  'cgCczzhDOoI',
#  'zoVj9AvyZ-c',
#  'NRfdELYWkKI',
#  'QRUdwXeWLT0',
#  '5BzJjXyyJ_M',
#  'VsBV1akZZbY',
#  'VVEbVVTZQRE',
#  '-dRgoqxU_zA',
#  'DMC-t_UbCL4',
#  'idEsa-T6oqs',
#  'RZJtIDUk8iQ',
#  'hZcOY2jXcEQ',
#  'Xzjfsd6M9CI',
#  'UA12S3oi0I8',
#  'QkCWFGQlh3M',
#  'o8F5jV-WLXw',
#  'UjrEFzq3hRk',
#  'KFhDsyAtgHs',
#  'rNH6wO9Vmmw',
#  'dolw_n6_kj4',
#  'YbAKX5Mry_s',
#  'DPelsQr5qfk',
#  '0-ydVZLkLJ0',
#  'DvB0ZIbAWQU',
#  'awcRGz8fut0',
#  '4Q43p0n0Nc0',
#  '92AbC-c5LjA',
#  'Fgz3vQ45c6k',
#  'CNfrXMOJIX8',
#  'dht6XvFAzl4',
#  'zjEYitgKjKg',
#  'OSm9E5ckgzo',
#  '8Z2QAMMCCks',
#  'NF7BIEe9EbU',
#  'Vgs870gTKZo',
#  'RufHg1_D8l8',
#  'qfFG4w1dJps',
#  '5oWbTA8Ia8A',
#  'XoyU6WB55qY',
#  '_K_PntZOl1c',
#  'JadVjOITgWU',
#  'HwOzHqWOtJw',
#  'onIyQCxUYkM',
#  'mLc3wVgzAdo',
#  '5-aJY749X1U',
#  'mMnAbJ-VjOY',
#  'PbJieWmBScQ',
#  'PmkbbRRNlfs',
#  'D1n_l5eEsxI',
#  'blm7dpgaPWs',
#  'CyYCU67brYM',
#  'Xl6VNCICYB0',
#  'DRF1At-GuEM',
#  'mFO6ifaXpYM',
#  'qSaCD8raSlY',
#  '0nZ8OlMo-j0',
#  'k0tI60ahka0',
#  'zCw9ILuKZhU',
#  '3E58VgS6l44',
#  'k5Z0IHp5FXI',
#  'am9tGTiVzbo',
#  'o_w-Ay2vH2o',
#  'CQ2yJCZpJHs',
#  'OwyFQ1X9D6s',
#  'dTsueb6ATJ8',
#  'Gn29vWj61_8',
#  'LNpLNhzv58E',
#  'RUEdg1ohSyw',
#  'xntpK8Dqbhs',
#  'kRvYDzAl--U',
#  'sqZcxTWiA-I',
#  'Z9cXvPd0iAk',
#  'ke7dhE1HhOc',
#  'vKz0YWdEOus',
#  'UcNZ0Z-e82Q',
#  'OQxkkLqT7QY',
#  'oZ-bffEUtJo',
#  'wHL8hlPHEPQ',
#  'RwYKZW_aJsE',
#  'qg_nWHy9rIQ',
#  'tFIh88iEyU0',
#  'vfMQuK9NCFI',
#  'pQ0SiPGmyEo',
#  'eMSCtKVueJ4',
#  'ADQBeFktUV4',
#  'HZ_QKsilh7g',
#  '0dDUqfLn-38',
#  'hGaq-8Exr_c',
#  'gTg_OMJ8x_I',
#  'jew9IzMEsio',
#  'RdJvCT0NKN0',
#  '__DIHoC6W04',
#  'lEgrh8DrKfY',
#  'exdM8pYWEYU',
#  'Q0UvC65EKkg',
#  'VrlO5ViHv5k',
#  '4XOzJ0am4R4',
#  'Lq7pYV32flo',
#  'gCrO4qj7pes',
#  'dfetQ2hzK0g',
#  '9Ej3izcONGQ',
#  '_2OFRTR97Ww',
#  'HnxPv71W43A',
#  'xVkNzXLn1AU',
#  'tdCsjo-loAo',
#  '6Z4e01pfb7I',
#  'H47Q9SFh7w0',
#  'NbWNShaspdM',
#  'BZcRtL4GFF8',
#  'Sc_TmFn3tCA',
#  'L83d4fzwtcw',
#  'ZdaTgAG4V_U',
#  'B2lRr0InwcA',
#  '9op5mSPbRE0',
#  '0S4J0DZ4Uh0',
#  'zPrqAp4jNGA',
#  'Tz3LzS1JGm4',
#  'reAz-8N0oiU',
#  'uFZBlgZrAlE',
#  'Tii1SakXBjA',
#  'WxpExqMX6WQ',
#  '1n0TZ_D0yOI',
#  'PxkBNAgCFSk',
#  'AjlbSD4igBY',
#  'ge94PPrMvn0',
#  'jXAhEhpZ2OA',
#  'yt15r1-8RuU',
#  'D59JDs0e2Tg',
#  'n1Jh8LXElwo',
#  '1BRqSXaNE1Y',
#  'VovZKWE1Fs0',
#  't0TqQELnGmQ',
#  'LXW7oUcHhXc',
#  '-ztVWwonWxw',
#  'HdvU_aLcpeg',
#  'oX6X6Ullpz8',
#  'wgJX4dMOn9s',
#  'wvaacCHVp1M',
#  '1NvktC2OG94',
#  'oT0STI-IU9Q',
#  'LGWBL8VGyX8',
#  'vjYPh7yhJBU',
#  'ydwBJ9nAVH0',
#  '9Tn1wZ_5-9s',
#  '7D8K2c6MFKg',
#  'cxKfpcUB-MY',
#  'M_y0_ieH6y0',
#  'jjOZtkcC5QI',
#  'M8R-NEAxtPg',
#  'qhLxk4teFhU',
#  'Q8gM96mBc6o',
#  'wJCZYVD6iHE',
#  'pc13JjRhp6s',
#  'wPdoQ56-XNc',
#  'jZZKohe1Y94',
#  'YjONR1QdHjg',
#  '3GABHdavCSY',
#  'a7QkptK1Sh8',
#  'OtotA-d4Z1M',
#  '2lCg5Nza1kI',
#  'o-edJvmDgMY',
#  '7t-oojX8-BQ',
#  'MVyXteVjl2M',
#  '7cTTakCjACI',
#  'pCbLb0JRdgk',
#  'ljLe3Kl9-Aw',
#  'aivhU6l4dHM',
#  '_uRtlnIoOJo',
#  'Yhdmtos_KxQ',
#  'WGuIaX6ep4Y',
#  'DFR4Va0Lsco',
#  '5m3slNuyhco',
#  'nB2QUeYCoX8',
#  'ZJjFuhVjnDo',
#  '_pTQBuITzGU',
#  'jupcxMGVoLc',
#  'QX0cZaGKZiw',
#  'd7nF3p1hu8A',
#  'NG1cziyuL7g',
#  'h-NVpDRG8bI',
#  'lxGBtXOdqYo',
#  'w22Vr3bkIzw',
#  'LSaQ53nkmMM',
#  'kgJxkL1CTLE',
#  'u3BJnelfcvI',
#  'kXBRPPIqCxY',
#  '4vft9bFKqQI',
#  '2RsUUoejrKU',
#  'bxUwJ8kk5Sc',
#  'I1kjAZHL-5c',
#  'PscwDMiB_g8',
#  'ISPU7YnjiEs',
#  'AumS9GdTkLo',
#  'GlQOqpUw5Jk',
#  'MsAWi8_trvg',
#  'xv-SOBL9JZs',
#  'qAjCxHb7xxU',
#  'YfFDEtO0LJ0',
#  'DnQp6kVq3Uc',
#  'MXqWztv7vOo',
#  'K8PEZz2jaJU',
#  'FSRHqkdH8RY',
#  'ZS01SuUk394',
#  'Cqh5aHdTdBc',
#  'wKVYTr0uypU',
#  'VZOrCF6gjPs',
#  'hlaCHgoCEbE',
#  '6o_KCXjz_C8',
#  'acCGp41ULNA',
#  'mZhKeTQNBNI',
#  'vGcIaT_Tnvg',
#  'DwuoXtpIe_g',
#  'Wot-klmVFr0',
#  'eXO4yxICxVg',
#  'eB9hTapxDJY',
#  'SdF78a2kkBw',
#  'HyQ_XyjwB7k',
#  'MOQDEQ8vop4',
#  '6cG-W3PVieA',
#  'h_pRoyF5v-M',
#  '3jHA0U_JPgw',
#  '-ZBwPr1BEDE',
#  '2jptdpocomk',
#  'uRkWm0nGHdo',
#  '0JsFCxtld10',
#  'nDNZBtdHp3w',
#  '1pmxvi2DzIU',
#  '_oMLH654wNo',
#  'o7a67eH8DFo',
#  'OaVoGCsw_Ew',
#  'rAyiRbT6G54',
#  'rHApFeVY4Q0',
#  '8ugJM0tyTnY',
#  'Hf-7NO5WBKo',
#  'aIzEPXV3KSQ',
#  'SlF9orW-KHY',
#  'druda_dBj24',
#  'BWV4cYG8zvI',
#  '7ndvZV2d3N4',
#  'vTGKuRGXl60',
#  '28gGJm6v3YY',
#  'IgAHDpFPYGc',
#  'CLPNSo95-EU',
#  'tcRnwg54UJI',
#  'nLmtWTOrZwQ',
#  'q8agvuAQ2GI',
#  'Q4o8swOsZZY',
#  'yoerCqWxpt4',
#  'jEtwscUfJQQ',
#  '9cyROQOxQiw',
#  'IC7fstN5gc4',
#  '6-lqtyaCkLQ',
#  'fJU8Kxc4s9I',
#  'adUqnMvnMYw',
#  '5cS8mEjpvEU',
#  'oDd7-a1Pt6M',
#  'HrRUw3UB2Gg',
#  't3KJejITMoI',
#  'rPc-FcyqDO0',
#  'v5pBpeOZApo',
#  'Cf_XAi2u1Q4',
#  'AdgCzdYxRTA',
#  'JhwxcH6zll4',
#  'YDCo7rwUSg0',
#  'JUVosxQ98-I',
#  'eb2Q4OH0tN8',
#  'n8LTPeOok98',
#  'pfxviBpF5tk',
#  '28anBKFtpo8',
#  'cL1qa5-Y7bo',
#  '18BS2mXuBSw',
#  '3WVFy7pyH0Q',
#  '9Cb8Zu3mpvs',
#  'T1svRTrtbKo',
#  'IBGpqt_RI-U',
#  'YrtE8p9mnhw',
#  'TzMzF9rbEhA',
#  'sigCZigMehI',
#  '0cp7fSIqT5s',
#  'rESJHrCSyoY',
#  '_oj5B1wCiTo',
#  'YMDAoCQPtZw',
#  'D2R9sPeJeWA',
#  'kX-laa_9f6g',
#  'yqR9u6gOLBE',
#  'H6akYvzgpRs',
#  'cETNY_kBCh0',
#  '2qPnv9AwPrM',
#  '5-99KSf9TDg',
#  'nujdMEbJj9E',
#  'Mh7mpZTL9wU',
#  'ADj9iGzCZDY',
#  'QMTnOnNJ2nA',
#  'qqlC3w5gPE4',
#  'K4TTRQC0_0M',
#  'YJ6GVkPy0nw',
#  '4zAOFtT0U0o',
#  'Jcebqkg3e_w',
#  'on2GIM8a9BU',
#  '-zsmFSBfjoU',
#  'f6B9CPJeU-Y',
#  'V4EHd8q1ZSA',
#  'CxiPBYbM5UQ',
#  'k0e2ikMj3zY',
#  'rBt0s6iKqQM',
#  'zi0q8Ri3WBE',
#  'YuVn-_szhnE',
#  'GWA7MA0dXig',
#  'n-4sNng6d3Y',
#  'yE8gRlKYqmg',
#  '4ko7cqSRDG8',
#  '5ARxo4hzmsQ',
#  '6WO1OaojAN4',
#  'oQn5SNRPpHI',
#  'FAcZLH2WldI',
#  '5O0BS-pgzr8',
#  '6ueMKu9L3L4',
#  'nyLF80JQbNk',
#  'kFDSOL1pUEk',
#  'SyCXUZj4zkA',
#  'HB56RpMdtnY',
#  'r4hsjowClRA',
#  'rimHdTVB0bw',
#  '8l7MoTqUeCg',
#  'KiepcyyIabw',
#  '0okwv4Eq2pk',
#  'O7NKEcPC41o',
#  'BuLk3Z_e5Yg',
#  'N58QL7iBftE',
#  'p2OZBKYurlw',
#  'YITF9reCyck',
#  'HOHz0w2rRAA',
#  'wsIXnPMJ8i4',
#  'Y_qzwokSo90',
#  '31se-O9lMJk',
#  'qiLy25u-1oU',
#  'QA9_QTtbSGM',
#  'CTInVl0vxmA',
#  '76Mv0Yi89Gs',
#  'E3tH76l_hTE',
#  'jp9kFae0rXc',
#  'liQBYlmomZo',
#  'D7F31nFnzMk',
#  '84fuFnN3E20',
#  '0czbZ6S5cqg',
#  'TwGu_lvVLkI',
#  'IzlJdaYyH78',
#  'bokjEqXf1Q4',
#  'CaY0Tomt6MA',
#  '4tidK7sxKJs',
#  'B6D3baHUAHE',
#  'qUNfJUsak80',
#  'XcUnptrNJAE',
#  '_K12svssPl4',
#  'Zcx52I74j1A',
#  'pdQCAj-bt3w',
#  'Fqu8F0oYTug',
#  'waZTsk_xgDs',
#  'iomgt-nhwDA',
#  '3awmW6QgPoI',
#  'v5Wudza7pQM',
#  '6SXTg8f_JuE',
#  'W86TJFzHDgk',
#  'n0ZtDbvGxzQ',
#  'OC52Ns2zZxg',
#  'IDsGoe3cDrs',
#  'CK7Gy-rX0Zo',
#  'Cfxfcpb44cM',
#  'vXe5_rjq3T4',
#  'y4-77edxb4U',
#  'Q70ae-Su5U8',
#  'T0hX_9ZyPQ0',
#  'lgdnnBu5om4',
#  '5FWpOZ7TWoY',
#  'nyQAwHJ4pbU',
#  'PO3C-Fb0XSU',
#  'KKUEvbd_JI0',
#  'kb5hrvXWeSI',
#  '6Ah8o5yPZHY',
#  'woGTLWVlnRc',
#  'MKS1c0A_l-0',
#  'imByCp-6H5c',
#  'w75wQ4buE8A',
#  '1bYfpzsSid4',
#  '_x_ZgDKXQGo',
#  '93HQLECcTVo',
#  'xjr5fGrZkFM',
#  'Xs9iyUYVtZ4',
#  'nKjFtCPYLss',
#  'Iw1Vp22a8uk',
#  'XfIiFUFuTFQ',
#  'KJWKHP_jXO4',
#  '5qQqDEiRcUc',
#  'z9l1zHrl4Fw',
#  'zdSr_Rka33o',
#  '3KPPEO6HKbc',
#  'mJKkTDKK23c',
#  'Rka4hZgNKIA',
#  'V3Q1Vvg5fCA',
#  'AAYoUu8eMeE',
#  'pq_TMjUy9Ms',
#  'ZyXCaa8rjOk',
#  'SdMZgwVycN0',
#  'FtgPvcwPgIA',
#  '6Y16Kob_wTA',
#  'fu28zbzOtD4',
#  '01ZhbZfoRGk',
#  'MJQlkGOLGQc',
#  'SrWnTuCXYwg',
#  'J_QzIQYsjE4',
#  'k8vqd3jlhFc',
#  'ccX7_WNgFYw',
#  'BYYUT9e1gqs',
#  'UrIa7hOrs-Q',
#  'TEqb-V1_nps',
#  '8KkNt07KVu4',
#  'lba5X8YHoao',
#  'mz6ezPajQuA',
#  'jAFp6cIsiC8',
#  'hITrJGZid_I',
#  'qafkqq5rYgQ',
#  'rNnHjKxYx2U',
#  'mXMb3LmKgGY',
#  '8kyIsCTgv80',
#  'Fk7raHeloCM',
#  'lTkMrsaQue0',
#  'kFQBAnzevjo',
#  'upy230cuC5Y',
#  'CGhXoiYnUzo',
#  'qQF2q5vDsrM',
#  '1MRiXlNa6_4',
#  'ht1SUSsvuC8',
#  'yqtZRnh8r7M',
#  'MxVCAWkPjoI',
#  'sdjU7m50rPE',
#  'jFJrhWUpJ5M',
#  'H1yMj1rmirM',
#  'vASTqKNY0sU',
#  'ekPs0qQtV3g',
#  'bRMR1vGC02o',
#  'aG59-Oe_QK8',
#  'PzHf6emfi70',
#  'jkVOVpvdgUE',
#  'KKI7Mo8Hu7s',
#  'IXhwktwTJDk',
#  'No370KOeu6A',
#  'JDeGC3Vxisc',
#  'U_4ij-8U9LE',
#  'BcfsvDNSioY',
#  'R40DRKzMLPU',
#  '2_L9Y8qfPRI',
#  'BLD_XAsIDwA',
#  'pw6VqERZgWA',
#  'FrhM8g3pdk4',
#  'Hl1ATitr0HM',
#  'rcGmu-ertkc',
#  'LowCg6RkO4w',
#  '6v3_Lbcv41w',
#  'zW0yHOmEzds',
#  'jz4SWCkpQXU',
#  'qQj6RC__wCk',
#  'AOBBv4M1g2c',
#  'Qh0M9YGuth0',
#  'Zd28GVfdd7k',
#  'oV3UMW58VnQ',
#  'bgLNCSH6dkA',
#  'JU0kTPk7VxE',
#  'Ru7tkJakhnU',
#  'n2Yp077YPmw',
#  'NgXF65nVI_I',
#  'y4r1SDejU6M',
#  'DMVNg4bf9Vo',
#  '_EDB_LlITdY',
#  '6l5afFDf0Yc',
#  'Lt-LCa_u4-w',
#  'RrY2-d0Jj9M',
#  's7L37ZJgdZM',
#  'fUKslb2pCUo',
#  'aijfjqjtIlw',
#  'PVIaDc7uWUg',
#  'k1yzbda3Zqc',
#  '7Lcf8oISI78',
#  'cLMXiMrfW9E',
#  '8kJcFGR39Eg',
#  '0StCckar5Ds',
#  'y-mSNIrOX78',
#  'IBqi6gECbl8',
#  'LuV5Ia3bRvY',
#  'IhqpcTxykAI',
#  'UKBxPCOWJqE',
#  'C4GKZQb0gdU',
#  'ux2pPHcHL5s',
#  'N1fdDmJuMZk',
#  'GDGl7HVC2VA',
#  '_3CpjzSNM1U',
#  'FrgXFv3y-qs',
#  'nGfKqZF-dzo',
#  'MuKfK8fkFao',
#  'MiAZahBm8-g',
#  '_eg_olLI9-A',
#  'PDJdkptTLi0',
#  'An5nBAXhHRY',
#  'Z-6xG5jRYlo',
#  'oetSP_ZArOY',
#  'w5w62IFymyE',
#  'okAMIbXXkwE',
#  'Ecy7FB-pgVQ',
#  'Cet9Sx0udBk',
#  'INByfW1RbFM',
#  'PuNaRAeyHj8',
#  'FsH-6BuFo7I',
#  ...]

# %%
playlist_id1 = []
allvideo_id = []
for i in range(len(channel_ids)):
    playlist_id1.append(dataframe.iloc[i]['playlist_all_video_id'])

playlist_id1
# Out:
# ['UU1jqQ11rUZe70O1j9XDk_Rw']

# %%
for i in range(len(channel_ids)):
    allvideo_id.append(get_video_ids(youtube, playlist_id1[i]))

# %%
allvideo_id
# Out:
# [['s6LTpRw0Tkc',
#   'xbmmU1Nz9nM',
#   'CjrZCAIXjJQ',
#   'nP1wNdTZsxs',
#   'JsoCAf1Qtq4',
#   'gmIDfThmDQM',
#   'AGK4lgDc0AI',
#   'skcOBh1f1qo',
#   'KQe6obvMWuU',
#   'h6Vqb-9CrAM',
#   'XEtNfg-GQ6Q',
#   'AGeG4wUupWs',
#   'aUb9Wdw9ghc',
#   'dksWFBR-EL0',
#   '0nqGBdQPkDQ',
#   'c2MWCIQOico',
#   'zdAIUzk2lWU',
#   'U0_1mvm3b5Q',
#   'o_g39MJ-k4E',
#   'QTHO7PmXUVk',
#   'Vz2sHaEe568',
#   'n3BlqSypjbM',
#   'wVpFzMo2yMo',
#   'Wk8MhAatXGk',
#   'XBlnc0C-tUg',
#   'TDOi_4BDUJQ',
#   '28pVsW_MeXo',
#   'hS3Pja5d8vg',
#   'PdHq55c4K6o',
#   'JEVpq0ekmcw',
#   'hEMQz8p6suU',
#   'eoIzMQ2lUmY',
#   '7a8NDWTjMgw',
#   'MY8WsRIKREo',
#   'gg_lUORachY',
#   'p7gNlg5OBYc',
#   '31Ygnn4RpMU',
#   '2g2Z3DkqTT0',
#   'ssG7BLLQAUs',
#   'E-zsx25-dvY',
#   'J7mnjuYdOf8',
#   '7mmopRte5rg',
#   'wttTQ0xtC5g',
#   'h8JfQkRv21U',
#   'OAhl8Prvpsw',
#   'JAwVW5cmh3Y',
#   'h-eezW0HXyE',
#   'McJdKxMpD9I',
#   'z6hXYAESDV4',
#   'jpY522ZD9IY',
#   'fFoQdFsn8kE',
#   'PJ4JHUUSLvI',
#   'z3CyWz-6ktw',
#   'LcQao0T362w',
#   'f7XK620MTWE',
#   'bA101aBTCSY',
#   'jsHkA-jQF6E',
#   'srZKUcPfXpw',
#   'Qd1LDppVanc',
#   'bsDfDOL_sVA',
#   'RApQoWOorSs',
#   'j7-zF9kGMoM',
#   'BpWfUB-13Sg',
#   '6tqNvRKRov4',
#   '7R17B-xNmBc',
#   '8UmMvUjM3Qo',
#   'oszPxEf95pM',
#   '3UQt3vpX5C8',
#   'BJCSnxsaEmQ',
#   'dIxTtTbBlGw',
#   'TslYSDHLG0U',
#   '6knTyCqgIYs',
#   'clz68cquTME',
#   '9ATxTWD6Rmk',
#   'EoGZANgO8X4',
#   'CRPYrKXRbcI',
#   'Wt494iUUrzY',
#   'NkKVlWAEfjM',
#   'ME1LVhEh0gA',
#   'k4BMz764ZGw',
#   'srRV1p3qW-4',
#   '-xiWq1r_i3M',
#   '4i5WD711vVI',
#   'FoEkM98KUWY',
#   '2-Iz-nsKQi0',
#   'OvQS2s3fwl8',
#   'dpEpyi1FN9I',
#   '7kgpXcQWuDw',
#   'OjoX9EG78WM',
#   'JXXcrwsCTTM',
#   'CtuxeIFrjlY',
#   'tCDzbxwjH3k',
#   '-9x4QDFoeW8',
#   '0O1tk4W5R4s',
#   'mEog7_t6IWY',
#   'Kl8P0WhyzsA',
#   'ycRHz2zTfO0',
#   'H_hLR04Tr1s',
#   'X8ZdiNJaNTY',
#   '14MMVMxbmBA',
#   'WdLjlKGAbZI',
#   'Eg46cb47bAo',
#   'ldqhI_y5gY4',
#   'fjai8rbOmLE',
#   'yJGyIhSy2Ww',
#   'FhSKtEvW2pM',
#   'm3ZyLhh0IyA',
#   'Npuqu75ctbY',
#   'SF7YcmEvrZ8',
#   'CVuSCq2PF00',
#   'Sgi_T1M4wgA',
#   'jCSkZSIcYos',
#   'qaKf9Vxuxdo',
#   'G9mAN6iELhw',
#   '9fzxH2f7-dA',
#   '5bsFR7dr2Bo',
#   '4dTolvsgxBE',
#   '50lbpMEpr6o',
#   'DAwKq192kwU',
#   'ES4PUvDdHsA',
#   'MMKVK8SyI3I',
#   'QJc6x6ChTJc',
#   'hTofzlU2R30',
#   'lUk1XVcH-hI',
#   'DDrf22B-Etk',
#   '1C9hxekOXY4',
#   'KYlsPCYawXY',
#   '8en6OJo_NGk',
#   'V-H8f5LolpU',
#   'rIutWRKWrtM',
#   'eOlzSTO8Eao',
#   'wx4QciG0U2U',
#   'iAz_-cz1PUc',
#   '-Afc8Jz0vvo',
#   'BZP_WQCIKwg',
#   'IiYDsBwFi3w',
#   'l80jV2ifM9E',
#   '8hlJg6iPWDY',
#   'Bdjxhh3PvRs',
#   'uMhPpzaGtj8',
#   'B_ojUko2nRo',
#   'zBldYWexKOA',
#   'S_jeWwrVGIA',
#   'FA6IADhwjFg',
#   'Tl56tZGr9II',
#   'WdzqgS6F8S8',
#   'qBiFBTx4rko',
#   'sekSQBkhPUU',
#   '0w1CmWLLwtc',
#   'RcJhvmzZBHk',
#   'ZnOFqZ8Z13I',
#   'vjDwnouUkP0',
#   'qq6HDhXqEFI',
#   '8JwZC3z3B7U',
#   'CS4MVNICkGM',
#   '9b3YJpO-4H0',
#   '3NVeEuQPezo',
#   'GYM8w9Wi9gs',
#   'QUir86vRyyo',
#   'frX3OZ9PBnw',
#   'mOhQEdTi-FM',
#   'BJjT9OCVRB8',
#   '9dB-1T86084',
#   'wxIglmSU3NY',
#   'G3EpqJnmwGo',
#   '3puoerb85zo',
#   'XzrRTqugqM4',
#   'MRV2D6-2vxw',
#   'spVWYmeJlEg',
#   'w1gCqtE2aVs',
#   'jkLTfTYGvwE',
#   'JsO7Sk8knmE',
#   '7fI1Sm9QvIA',
#   'hDZ6ztSASxg',
#   'UcvxWs2c4D4',
#   'KiRbR-Biwc8',
#   'IKYNY6ayEc8',
#   'bu-peZHqNY0',
#   'GSnKo8E5bac',
#   'kiCXL06xECI',
#   'UqVv9WChW5c',
#   '1ID2KMcjuz0',
#   '5k8zDQzdC38',
#   'vge-M_JUUO4',
#   'pFmo9tnY76Y',
#   '9JWfbvIN-W8',
#   'd0UwAxiiwqU',
#   'CVxT8_KbIMs',
#   'D6Y6VdDrPSI',
#   'vuX46ZJHAMA',
#   'sUiNdgBk1Wc',
#   'ktb0KBp2ESs',
#   'YEVoRrKGYZo',
#   'LaDMUcXIzyo',
#   'XLZ9DVACF1A',
#   'TX5uyciqUrM',
#   'FJE62LlX7Ro',
#   'ySja2j1MERs',
#   'R4LXnSTdjfQ',
#   '-K0A0igsMCI',
#   'u4biYUyisvI',
#   'mUfEP2Na61w',
#   'yc_ZCMVOC_g',
#   'Q5x48iTgAnI',
#   '3cUEmbaZyI0',
#   'DV_cU_UIHIM',
#   '4MCN9lCCl_o',
#   '1gmjJ2MPAZY',
#   'Pgbl2yiuUVs',
#   '9NF1Apb6c7U',
#   'X2LOheW35Lo',
#   'gSW1PO3E88I',
#   'P5PGkLMRxzY',
#   'AvT2s55IaDw',
#   '-wdcEPG_8cI',
#   '3TQ4qcM8H1A',
#   'U8FWpnyzDQM',
#   'jil9CP1ctbU',
#   'EROd1paalrs',
#   'hq9HPbIvtGY',
#   'Bjjk_N3QdAA',
#   'k8iAPvEHiJk',
#   'Ht1_IcOb5r0',
#   'mvdGbY0rN0U',
#   'Ze25TQiVB0Y',
#   'JaoCVX-9VVQ',
#   'q_YOJQ-PV1c',
#   'yi_y3idCing',
#   'Dljpy1OBg94',
#   'kMz439RqgcE',
#   'XUUmKUzzUZA',
#   '9rrxCVhDDmI',
#   'JVJhDadkjVM',
#   '0rNVt-OByYk',
#   'Dvjj8iDCh9g',
#   'KYyO-1puX0o',
#   '8_s5YOd1HSw',
#   'cbXvUGDa63o',
#   '_H6kvV46oXQ',
#   'XMAqOHaI1ng',
#   '3bE5Vdiu0sc',
#   'FQrR9CphdAg',
#   'fYpwy9hSPNA',
#   'jD-72r-Fekw',
#   'tw7r2z_Ni-k',
#   'CAGS1cnSsX0',
#   'nBS_mApCMnc',
#   'BHmmUErcahk',
#   'UhVaLswNN-E',
#   'S1uwniW5HBI',
#   'KWPfUR4euj4',
#   '8rCTPoTbALc',
#   '-AZlj4sKjrU',
#   'KC1inGaVVOY',
#   'xsNDU7DuVU8',
#   'VU1BLAhmnxQ',
#   'mjrskN_84do',
#   'jOZH1grK7OQ',
#   'EeYj1bDsQro',
#   'CxeDDS07CYE',
#   'v5KtyyIolmE',
#   'j7sxKyItcQA',
#   'U3v-RUu_0w4',
#   'UFu5tu3_R8Q',
#   '1XjZHMrIpr8',
#   'E3SKVL_JgG0',
#   'xTx1YaYHo0I',
#   'f4D3Nk5MsDc',
#   'hbCpS3aeHlY',
#   'H2_yn8CZUTk',
#   '46aLLXIiMKI',
#   'fxRYisdjLvA',
#   'XCtIKlGkbok',
#   'EoctdfO7qkc',
#   '3H1OC96D6I8',
#   'pdVe4_U4l4M',
#   'goyDqYHBoAI',
#   'wJpsffSUhKQ',
#   'T8kCt4dy1uo',
#   'BuC8vr4xCdg',
#   'EamN1zGNur4',
#   '7vebpNG0Z6w',
#   'h3t8nhWIIcA',
#   '2PjXSAfNXeo',
#   'fv15bwXY9dw',
#   'JIsCDOMOoyU',
#   'nvawAVqbJSE',
#   'RlmYqPKQONE',
#   'XtIT0eau4Rg',
#   '12vc9LLUvvQ',
#   'YytftygIMvE',
#   '4XRbVqP4Vnw',
#   '_Sj7uGpgtnc',
#   'wED-Vi-ahpU',
#   'AOblr9FsKCA',
#   'iqVRc7EV09k',
#   'DFLrwg2eCcA',
#   'lVcU1c0mQmI',
#   '3xeIZHfjPz4',
#   't9oxTd2hgAM',
#   '_OgTYBnMY18',
#   'VVyGEbEzI1U',
#   'LtdjCaN4OgQ',
#   'oWYMIJtXiHg',
#   'oJuY1D_LvZ0',
#   'vC0IpE_Dw_A',
#   '5sYTHl5P074',
#   'cAGY2J_hg7A',
#   'qW02bv3wvx0',
#   'oME6SZ7Z7K0',
#   'qEKy7BNFOp0',
#   '9jvOq8cVf7o',
#   'bd7dgV4wyPg',
#   '98sPQaXM5Hg',
#   'n4VYeYyC8DA',
#   '28dB0m-BmQA',
#   'HgseCLOOLnM',
#   'X30q0h7mWsw',
#   'CwJS-CkkrOY',
#   'ojXuZDQaf0c',
#   '8AIP8lXIezw',
#   'FZNcHYNZCg4',
#   'N1N8fauDj9U',
#   'k-g6eBLAego',
#   'qXNH6qilk3w',
#   '8_gE8wy4JjE',
#   'p8Y_yIi9eds',
#   'c7sq7aFnLLE',
#   'H9JN_pabkuI',
#   '3-2gud7B2UI',
#   'kPbsqb3qyRI',
#   'lIrhA1AHP-I',
#   'fWMwMin8Tco',
#   '-STcroBnsck',
#   '-WLYdjq0Trs',
#   'sz9JZbzDGvU',
#   'FCnCCFXm5RI',
#   'O7jvlBL6oVA',
#   'I2-kNuYuP-E',
#   'K1NxMaEsvO8',
#   'DpQu6tskX8I',
#   'kaKPYuxDUeU',
#   '5g6eszyZT5Y',
#   'NHaaO6HQdPo',
#   'zr7JJzt5RMc',
#   'jsDkX1Um6Ss',
#   'oqFhDicgq2Q',
#   'UViF3AACrDY',
#   'n2xA5dpY_iY',
#   'VHevkiOOpFk',
#   'ZAh8zJlEGuw',
#   'wcMuB-LgWuM',
#   'FIxpEfPMc-8',
#   'TALKq6rZWew',
#   'Yz9x3keCAnc',
#   'k0wKZduOAqQ',
#   'qBJUAklEgMY',
#   'JH11qvZMeYk',
#   'S6XyXnOiGys',
#   'shO6NY20idA',
#   'PGePN42of9s',
#   'eH-5tzk5fxU',
#   'eR5B1_DT5c0',
#   'aAmHscLpGbE',
#   '0cyfqU7dE6Y',
#   'chxEJyV7OYI',
#   'BV5R3BULW-A',
#   'uZByp0ln2SA',
#   '8ip8S_QGAcg',
#   'EPwMJGT5dws',
#   'QbQTyriazR8',
#   'IDmwdMplSfM',
#   'MqrgRASkeKE',
#   'uGN1RaFcl6Y',
#   'joY1hGhJIHo',
#   'aVoPp5QA4ww',
#   'KKnRivQdIIU',
#   'Z2fmygYr7O0',
#   'Vb8p2H-dx2E',
#   'E4vVKei3fGQ',
#   'ITFkB7Il5hM',
#   'wclCUKfeQyM',
#   '9VbLLwitut0',
#   'DYLIC_xK1C4',
#   '9lxtoYYk9X8',
#   'D8klgcLgCuc',
#   'te5jg_Z5Cms',
#   'HJCrSPJ4TyI',
#   '1GlAvzyvbtA',
#   'x2pehgkvgQk',
#   '4tATiU0VpGs',
#   'tJcN39hbcTM',
#   'yW4EcJNrDdo',
#   'dOwbb5mLPxg',
#   'a9j1z6OZP3Q',
#   'sWVVZHkn4yw',
#   'feu2ZhiI6w4',
#   'SKfN1nO8vvY',
#   'fLZRMRFzh8E',
#   'vs3A2Bkp_nw',
#   'SgshUnTvtpk',
#   'KBVagkvvTD4',
#   'GGKHQwJyXFs',
#   'uYNS-Yncoeo',
#   'GsF8zzmOznU',
#   'XSeYuyiO0Kc',
#   'eiZ4aVeW-_I',
#   'osgjZmYQB0k',
#   'Ra_-3NqqRYc',
#   'I-_4k4o4upk',
#   'yjDrCtLStI0',
#   'TdayDnoZGQo',
#   '_q0eBhVfxJk',
#   '5ev4G4Zh1Cg',
#   'JhzpvwzpXK4',
#   'NMZ2Ejp0SbM',
#   'PuIcK1Yn6ZQ',
#   'T3-KE_NBANM',
#   'vRT3TQHJ8bw',
#   'VxxLXvdVRYk',
#   '5tdFirDii34',
#   'kREqoWGiRBU',
#   'il_niCCHfMU',
#   'RknoF_6GeGk',
#   '9TkujxZCLCU',
#   'gtY3eYOivU8',
#   '1ckG2IvIutE',
#   'hmj0c_FcE8E',
#   'J4qq7ZU2n4o',
#   'CpiZQbDRVKA',
#   'KutaeB7j4JU',
#   'P8szk2XJroY',
#   'RPFkPFc68-Y',
#   'C9qYUIwdWbk',
#   'Ze12hxdSHdM',
#   'wHrKlWg6ZKw',
#   'sUx9s6Ox42k',
#   'nNibFHAoaSk',
#   'OSd9A1Hhp2M',
#   '2EwJmd6s8zg',
#   'CVH657_BhPo',
#   'dh-Kzk63gz0',
#   'XAxsD9rLYVs',
#   'EUxJfb5VUWA',
#   'MgYuzL1TZ50',
#   'Eqcp47s57Bs',
#   'RaZ6UHbYd6w',
#   '98A1blEGJkU',
#   'mw_I7tMOfmU',
#   'sXsHSWVKbIY',
#   'OwCb4vq-5_g',
#   'mPqyr8enffM',
#   'cXKnkyjy8ug',
#   'JNbR2uFSFKQ',
#   'q8IThFYMAUo',
#   'nDNo-pAF4G4',
#   'lrCW6Q1id5Y',
#   'cmzH5aXe_Pc',
#   '9gPatnawaWk',
#   'slSZxIcqdBA',
#   'ZgR-vt04p6o',
#   'INj4tEXRFTA',
#   'oulHyR-uLmU',
#   'BF-NELR8TmY',
#   'gCIOSGDUFxM',
#   '14bSuoYLv6g',
#   'rbBuS0oO3F4',
#   'drcteTXc22E',
#   'UEiYbJt7ehc',
#   'fnqlf36lwzw',
#   '9p4RwGlgI04',
#   '0CqQV2qrHwU',
#   'eV9pn6JNa9c',
#   'BHDWH-eSZrE',
#   'cdKqFvov2kw',
#   '09ssTp3q7dY',
#   'yl3lLdxpy5g',
#   'eDqaWZAgSdY',
#   'ufXx5n_es_s',
#   'tGcFq-10ios',
#   '6hW7o6d0cPE',
#   '0IRtVszT-aM',
#   'sG6-UOVoaiE',
#   'R0xwCNe8N3Q',
#   '3Hf5zUAQQv0',
#   '1BrWFgI_qGc',
#   'rZS-xX5TM-w',
#   '2qa_fgiJZII',
#   'rdcyGbPq5T8',
#   '2-onggTQ2kY',
#   'HFYjPRw2Chc',
#   'k5dXpWnlkMc',
#   'UAYs-k6Z5Gs',
#   'idjWwVsin6M',
#   'uI9z0LIP2tM',
#   'ABWkp47d-Bg',
#   'LvaVPm7XhAQ',
#   'U_iOPOMdj2Y',
#   'dlr-fC8ZkCk',
#   'ueogf2mSa5I',
#   'KbhMwgGKf40',
#   'OUd9cvj87G4',
#   'WDZstHc3jZs',
#   'RmFP_rb4J6o',
#   '3wV2-xgeidg',
#   'qGYyaPI_7WU',
#   'X5GHRk_ghmc',
#   'ZKRxXojvhdY',
#   '3s-0hX42yKE',
#   'U_40U348BjY',
#   'iYNljkzlmn0',
#   'fyXzwaV2PSI',
#   'PhwmD_lvdyY',
#   'WJgTmEZ5hHg',
#   'rPqsJsv6A6Q',
#   'jjq8lWbcwqs',
#   'IBE5sngX4AE',
#   '-_Pz-6-gIIQ',
#   'CeKsnkNBXmE',
#   'TSkUVJ13uj8',
#   'FyuPQTpXMhQ',
#   'LcB6oCpCwfg',
#   '1LKI1vQbCzM',
#   'nz36Ym5vl20',
#   'HCT2CVOPov0',
#   'VQBiQtZQeC8',
#   'C4bynzLl45w',
#   'zdfnHsedO_g',
#   'ExN0M83ZL1M',
#   'L9caCq12UQo',
#   'zIzBpPt1gY8',
#   'sYuq1L00kzA',
#   'sfGEILnRd0g',
#   'ruvndT8L7jE',
#   'Ze6YycP5_qY',
#   'JCiShqnA7PE',
#   'v636jVurQZI',
#   'CDgjs2rGSts',
#   'giP59rqQ0Cw',
#   'eFKeXUY1hmQ',
#   'a3L78iasfYg',
#   'lYPOpjAG3ns',
#   'QPa-6fnmF4c',
#   'lZwImAYp_es',
#   '5tb6Lz1oeqY',
#   'x811d6K2ya4',
#   'aZuvxd9a_EA',
#   'YnVcicKmn4E',
#   'qSmyIKjhON0',
#   '6dcnGetbM1E']]

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               Views = video['statistics']['viewCount'],
                               Likes = video['statistics']['likeCount'],
                               #Dislikes = video['statistics']['dislikeCount'],
                               Comments = video['statistics']['commentCount']
                               )
            all_video_stats.append(video_stats)
     
    return all_video_stats

# %%
#for i in range(5):
display(get_video_details(youtube, allvideo_id[0]))
# Out:
# [{'Title': 'Prima o poi......',
#   'Published_date': '2021-12-20T14:33:30Z',
#   'Views': '643',
#   'Likes': '62',
#   'Comments': '0'},
#  {'Title': 'COME RIMUOVERE IHS DELLA CPU, VERSIONE ESTESA',
#   'Published_date': '2016-10-06T14:00:02Z',
#   'Views': '6980',
#   'Likes': '175',
#   'Comments': '129'},
#  {'Title': 'COME RIMUOVERE IHS DELLA CPU, VERSIONE RIDOTTA',
#   'Published_date': '2016-09-29T14:00:02Z',
#   'Views': '2300',
#   'Likes': '77',
#   'Comments': '31'},
#  {'Title': 'WD RED 3TB, UNBOXING',
#   'Published_date': '2016-09-22T14:00:08Z',
#   'Views': '2737',
#   'Likes': '103',
#   'Comments': '15'},
#  {'Title': 'PARALUCE CANON 50mm, ES 62, UNBOXING',
#   'Published_date': '2016-09-15T14:00:01Z',
#   'Views': '2427',
#   'Likes': '35',
#   'Comments': '13'},
#  {'Title': 'FILTRO GIALLO PER OBIETTIVI 50mm, UNBOXING',
#   'Published_date': '2016-09-08T14:00:02Z',
#   'Views': '1746',
#   'Likes': '41',
#   'Comments': '10'},
#  {'Title': 'CARICABATTERIE PORTATILE USB IHARBORT, UNBOXING',
#   'Published_date': '2016-09-01T14:00:00Z',
#   'Views': '775',
#   'Likes': '42',
#   'Comments': '29'},
#  {'Title': 'ZAINO PER COMPUTER PORTATILE',
#   'Published_date': '2016-08-25T14:00:05Z',
#   'Views': '3235',
#   'Likes': '57',
#   'Comments': '16'},
#  {'Title': 'TRUST GXT 207 XXL, UNBOXING',
#   'Published_date': '2016-08-18T14:00:01Z',
#   'Views': '2024',
#   'Likes': '71',
#   'Comments': '42'},
#  {'Title': 'SUPPORTO SMARTPHONE PER TREPPIEDE, UNBOXING',
#   'Published_date': '2016-08-11T14:00:03Z',
#   'Views': '980',
#   'Likes': '43',
#   'Comments': '10'},
#  {'Title': 'SMARTWATCH U8, UNBOXING',
#   'Published_date': '2016-08-04T14:00:03Z',
#   'Views': '2537',
#   'Likes': '87',
#   'Comments': '50'},
#  {'Title': 'POWERBANK PER SMARTPHONE',
#   'Published_date': '2016-07-28T14:00:00Z',
#   'Views': '971',
#   'Likes': '55',
#   'Comments': '13'},
#  {'Title': 'PASTA TERMICA NT H1, UNBOXING',
#   'Published_date': '2016-07-21T14:00:00Z',
#   'Views': '1410',
#   'Likes': '44',
#   'Comments': '8'},
#  {'Title': 'PROGRAMMI DIAGNOSTICA IN BOOT',
#   'Published_date': '2016-07-19T14:00:03Z',
#   'Views': '3404',
#   'Likes': '114',
#   'Comments': '43'},
#  {'Title': 'PARALUCE SP 67mm, UNBOXING',
#   'Published_date': '2016-07-14T14:00:00Z',
#   'Views': '813',
#   'Likes': '20',
#   'Comments': '28'},
#  {'Title': 'PROGRAMMI DA INSTALLARE DOPO UNA FORMATTAZIONE',
#   'Published_date': '2016-07-12T14:00:03Z',
#   'Views': '29306',
#   'Likes': '657',
#   'Comments': '154'},
#  {'Title': 'PARALUCE MORBIDO 67mm, UNBOXING',
#   'Published_date': '2016-07-07T14:00:03Z',
#   'Views': '1098',
#   'Likes': '25',
#   'Comments': '12'},
#  {'Title': 'CODICI GRATIS A VALANGA',
#   'Published_date': '2016-07-05T14:00:02Z',
#   'Views': '80292',
#   'Likes': '1448',
#   'Comments': '164'},
#  {'Title': 'KIT PULIZIA OBIETTIVI',
#   'Published_date': '2016-06-30T14:00:03Z',
#   'Views': '2840',
#   'Likes': '46',
#   'Comments': '23'},
#  {'Title': 'ADVANCED SYSTEMCARE, TUTORIAL',
#   'Published_date': '2016-06-28T14:00:02Z',
#   'Views': '2998',
#   'Likes': '133',
#   'Comments': '67'},
#  {'Title': 'SERIALI GRATIS PER TUTTI',
#   'Published_date': '2016-06-27T19:00:01Z',
#   'Views': '4024',
#   'Likes': '174',
#   'Comments': '47'},
#  {'Title': 'KAAVIE RC 6, telecomando per fotocamere, Unboxing',
#   'Published_date': '2016-06-23T14:00:02Z',
#   'Views': '811',
#   'Likes': '35',
#   'Comments': '18'},
#  {'Title': 'Come formattare un hard disk per Mac Apple',
#   'Published_date': '2016-06-21T14:00:07Z',
#   'Views': '6984',
#   'Likes': '31',
#   'Comments': '9'},
#  {'Title': 'COME AGGIORNARE I DRIVER DEL PC',
#   'Published_date': '2016-06-19T16:00:01Z',
#   'Views': '19512',
#   'Likes': '547',
#   'Comments': '104'},
#  {'Title': 'CUSTODIA ALCATEL C9',
#   'Published_date': '2016-06-16T14:00:02Z',
#   'Views': '669',
#   'Likes': '36',
#   'Comments': '10'},
#  {'Title': 'Come formattare un hard disk per Linux',
#   'Published_date': '2016-06-14T14:00:01Z',
#   'Views': '11119',
#   'Likes': '75',
#   'Comments': '7'},
#  {'Title': 'Come inserire un SSD in un Asus',
#   'Published_date': '2016-06-09T14:00:00Z',
#   'Views': '23266',
#   'Likes': '138',
#   'Comments': '28'},
#  {'Title': 'Come formattare un hard disk per la Cache Linux Swap',
#   'Published_date': '2016-06-07T14:00:30Z',
#   'Views': '820',
#   'Likes': '20',
#   'Comments': '3'},
#  {'Title': 'CARTE PER IL BILANCIAMENTO DEL BIANCO',
#   'Published_date': '2016-06-02T14:00:01Z',
#   'Views': '4989',
#   'Likes': '78',
#   'Comments': '147'},
#  {'Title': 'Come formattare in fat32 con Gparted',
#   'Published_date': '2016-05-31T14:00:01Z',
#   'Views': '2568',
#   'Likes': '36',
#   'Comments': '14'},
#  {'Title': 'Come applicare la pasta termica, versione estesa',
#   'Published_date': '2016-05-26T14:00:03Z',
#   'Views': '5501',
#   'Likes': '91',
#   'Comments': '20'},
#  {'Title': 'Come creare delle partizioni con Gparted',
#   'Published_date': '2016-05-24T14:00:01Z',
#   'Views': '6488',
#   'Likes': '55',
#   'Comments': '8'},
#  {'Title': 'SERIALI GRATIS...UNA VALANGA DI SERIALI!',
#   'Published_date': '2016-05-20T14:00:00Z',
#   'Views': '3474',
#   'Likes': '349',
#   'Comments': '467'},
#  {'Title': 'Come applicare la pasta termica, versione ridotta',
#   'Published_date': '2016-05-19T14:00:00Z',
#   'Views': '15161',
#   'Likes': '225',
#   'Comments': '51'},
#  {'Title': 'Come convertire un Hard disk da MBR a GPT',
#   'Published_date': '2016-05-17T14:00:03Z',
#   'Views': '12693',
#   'Likes': '171',
#   'Comments': '36'},
#  {'Title': 'NVIDIA GTX 960 EVGA, UNBOXING',
#   'Published_date': '2016-05-12T14:00:01Z',
#   'Views': '1488',
#   'Likes': '99',
#   'Comments': '30'},
#  {'Title': 'Come convertire un Hard disk da MBR a GPT con Gparted',
#   'Published_date': '2016-05-10T14:00:00Z',
#   'Views': '9832',
#   'Likes': '60',
#   'Comments': '15'},
#  {'Title': "Come accendere l'alimentatore senza interruttore",
#   'Published_date': '2016-05-05T14:00:01Z',
#   'Views': '4221',
#   'Likes': '82',
#   'Comments': '21'},
#  {'Title': 'Come abilitare il Secure Boot per Windows',
#   'Published_date': '2016-05-03T14:00:02Z',
#   'Views': '3207',
#   'Likes': '62',
#   'Comments': '19'},
#  {'Title': 'TUBO ESTENSORE MACRO',
#   'Published_date': '2016-04-28T14:00:02Z',
#   'Views': '6262',
#   'Likes': '112',
#   'Comments': '305'},
#  {'Title': 'Come abilitare il Secure Boot per Linux o altri',
#   'Published_date': '2016-04-26T14:00:02Z',
#   'Views': '1103',
#   'Likes': '47',
#   'Comments': '11'},
#  {'Title': 'CARTOON NANIME VIDEOTAG #5',
#   'Published_date': '2016-04-21T14:00:01Z',
#   'Views': '1132',
#   'Likes': '87',
#   'Comments': '31'},
#  {'Title': 'SONO TORNATO',
#   'Published_date': '2016-04-18T15:00:02Z',
#   'Views': '2539',
#   'Likes': '294',
#   'Comments': '128'},
#  {'Title': 'Come trovare le parole chiavi con Tubebuddy',
#   'Published_date': '2015-12-15T15:00:00Z',
#   'Views': '3408',
#   'Likes': '133',
#   'Comments': '109'},
#  {'Title': 'Bulk Find, Replace, Append  con Tubebuddy',
#   'Published_date': '2015-12-08T15:00:01Z',
#   'Views': '784',
#   'Likes': '43',
#   'Comments': '17'},
#  {'Title': 'Come creare delle miniature con Tubebuddy',
#   'Published_date': '2015-12-01T15:00:00Z',
#   'Views': '1561',
#   'Likes': '97',
#   'Comments': '27'},
#  {'Title': 'Come gestire le annotazioni di Youtube con Tubebuddy',
#   'Published_date': '2015-10-05T14:00:02Z',
#   'Views': '1232',
#   'Likes': '57',
#   'Comments': '77'},
#  {'Title': 'QUANTO SEI NERD, VIDEOTAG #4',
#   'Published_date': '2015-10-02T14:00:00Z',
#   'Views': '2719',
#   'Likes': '168',
#   'Comments': '53'},
#  {'Title': 'Come gestire le Cards di Youtube con Tubebuddy',
#   'Published_date': '2015-09-29T14:00:02Z',
#   'Views': '926',
#   'Likes': '69',
#   'Comments': '13'},
#  {'Title': 'Come installare Tubebuddy',
#   'Published_date': '2015-09-25T16:30:00Z',
#   'Views': '3011',
#   'Likes': '157',
#   'Comments': '52'},
#  {'Title': 'Unboxing Webcam Logitech C930e, ITA',
#   'Published_date': '2015-09-17T14:00:01Z',
#   'Views': '8426',
#   'Likes': '185',
#   'Comments': '67'},
#  {'Title': 'Come aumentare le visualizzazioni con Tubebuddy',
#   'Published_date': '2015-09-04T14:00:02Z',
#   'Views': '16313',
#   'Likes': '625',
#   'Comments': '161'},
#  {'Title': 'Unboxing XCSOURCE Adattatore Cokin P Serie LF78, Colorati',
#   'Published_date': '2015-09-03T14:00:01Z',
#   'Views': '975',
#   'Likes': '36',
#   'Comments': '12'},
#  {'Title': 'Come controllare una reflex con il pc',
#   'Published_date': '2015-08-31T14:00:00Z',
#   'Views': '16237',
#   'Likes': '201',
#   'Comments': '67'},
#  {'Title': 'CERCO IL VOSTRO SUPPORTO',
#   'Published_date': '2015-08-28T14:00:00Z',
#   'Views': '1678',
#   'Likes': '166',
#   'Comments': '73'},
#  {'Title': 'Trasformare una reflex in webcam con GioPizzi',
#   'Published_date': '2015-08-25T14:00:03Z',
#   'Views': '74753',
#   'Likes': '1188',
#   'Comments': '158'},
#  {'Title': 'Le migliori impostazioni per Sony Vegas con Kevin Believe',
#   'Published_date': '2015-08-24T14:00:00Z',
#   'Views': '8266',
#   'Likes': '374',
#   'Comments': '147'},
#  {'Title': 'How to transform windows  7 to Red Alienware',
#   'Published_date': '2015-08-22T08:00:03Z',
#   'Views': '2193',
#   'Likes': '40',
#   'Comments': '13'},
#  {'Title': 'QUALE TECNOLOGIA PREFERISCI VIDEOTAG #3',
#   'Published_date': '2015-08-21T14:00:00Z',
#   'Views': '1276',
#   'Likes': '109',
#   'Comments': '65'},
#  {'Title': 'How to transform windows  7 to XP',
#   'Published_date': '2015-08-21T08:00:02Z',
#   'Views': '1783',
#   'Likes': '31',
#   'Comments': '7'},
#  {'Title': 'How to transform windows  7 to Vista',
#   'Published_date': '2015-08-19T08:00:00Z',
#   'Views': '989',
#   'Likes': '38',
#   'Comments': '8'},
#  {'Title': 'Come realizzare il GREEN SCREEN su Adobe Premiere con ErSatto',
#   'Published_date': '2015-08-18T14:00:01Z',
#   'Views': '8993',
#   'Likes': '207',
#   'Comments': '44'},
#  {'Title': 'DOVREI SMETTERE DI FARE VIDEO?',
#   'Published_date': '2015-08-16T12:44:58Z',
#   'Views': '2391',
#   'Likes': '227',
#   'Comments': '79'},
#  {'Title': 'How to transform windows  7 to Metro',
#   'Published_date': '2015-08-16T08:00:01Z',
#   'Views': '913',
#   'Likes': '25',
#   'Comments': '12'},
#  {'Title': 'How to transform windows  7 to Blue Alienware',
#   'Published_date': '2015-08-15T08:00:01Z',
#   'Views': '956',
#   'Likes': '18',
#   'Comments': '27'},
#  {'Title': 'How to transform windows  7 to Green Alienware',
#   'Published_date': '2015-08-14T08:00:00Z',
#   'Views': '709',
#   'Likes': '23',
#   'Comments': '1'},
#  {'Title': 'Unboxing TV BOX Media player con Android Kitkat',
#   'Published_date': '2015-08-13T14:00:01Z',
#   'Views': '8492',
#   'Likes': '91',
#   'Comments': '25'},
#  {'Title': '3 programmi per navigare veloce con Jakidale',
#   'Published_date': '2015-08-12T14:00:00Z',
#   'Views': '3210',
#   'Likes': '191',
#   'Comments': '16'},
#  {'Title': 'How to transform windows  7 to Angry Birds Space Game',
#   'Published_date': '2015-08-09T08:00:00Z',
#   'Views': '979',
#   'Likes': '17',
#   'Comments': '8'},
#  {'Title': 'How to transform windows  7 to Angry Birds Rio Game',
#   'Published_date': '2015-08-08T08:00:01Z',
#   'Views': '2595',
#   'Likes': '26',
#   'Comments': '4'},
#  {'Title': 'How to transform windows  7 to Mac OS X Orange',
#   'Published_date': '2015-08-07T08:00:00Z',
#   'Views': '718',
#   'Likes': '18',
#   'Comments': '10'},
#  {'Title': 'Unboxing spallaccio SunSmart , RL 04+F0+M1+C',
#   'Published_date': '2015-08-06T14:00:00Z',
#   'Views': '1085',
#   'Likes': '34',
#   'Comments': '7'},
#  {'Title': 'How to transform windows  7 to Windows 8',
#   'Published_date': '2015-08-05T08:00:02Z',
#   'Views': '997',
#   'Likes': '29',
#   'Comments': '13'},
#  {'Title': 'How to transform windows  7 to Mac OS X Gold',
#   'Published_date': '2015-08-02T08:00:00Z',
#   'Views': '871',
#   'Likes': '25',
#   'Comments': '14'},
#  {'Title': 'How to transform windows  7 to Snow Leopard',
#   'Published_date': '2015-08-01T08:00:00Z',
#   'Views': '550',
#   'Likes': '13',
#   'Comments': '0'},
#  {'Title': 'How to transform windows  7 to iOS 7',
#   'Published_date': '2015-07-31T08:00:00Z',
#   'Views': '761',
#   'Likes': '25',
#   'Comments': '12'},
#  {'Title': 'Unboxing spallaccio stabilizzatore SunSmart',
#   'Published_date': '2015-07-30T14:00:02Z',
#   'Views': '1999',
#   'Likes': '42',
#   'Comments': '6'},
#  {'Title': 'How to transform windows  7 to Angry Birds StarWars Game',
#   'Published_date': '2015-07-29T08:00:01Z',
#   'Views': '497',
#   'Likes': '14',
#   'Comments': '4'},
#  {'Title': 'Come trasformare un file Word in PDF online con MrSimonoh',
#   'Published_date': '2015-07-27T14:00:00Z',
#   'Views': '5305',
#   'Likes': '56',
#   'Comments': '16'},
#  {'Title': 'How to transform windows  7 to Mac OS X',
#   'Published_date': '2015-07-26T08:00:01Z',
#   'Views': '1030',
#   'Likes': '32',
#   'Comments': '10'},
#  {'Title': 'How to transform windows  7 to Xbox',
#   'Published_date': '2015-07-24T00:30:00Z',
#   'Views': '2270',
#   'Likes': '52',
#   'Comments': '5'},
#  {'Title': 'Unboxing Rode Video Mic Pro',
#   'Published_date': '2015-07-23T01:00:00Z',
#   'Views': '934',
#   'Likes': '78',
#   'Comments': '10'},
#  {'Title': 'How to transform windows  7 to Linux Gnome',
#   'Published_date': '2015-07-22T08:00:00Z',
#   'Views': '1714',
#   'Likes': '20',
#   'Comments': '7'},
#  {'Title': 'Come mettere una password ad un file Word con Doctor Game',
#   'Published_date': '2015-07-21T14:00:00Z',
#   'Views': '1258',
#   'Likes': '47',
#   'Comments': '11'},
#  {'Title': 'Come convertire un PDF in WORD online con Davidekyo',
#   'Published_date': '2015-07-20T14:00:01Z',
#   'Views': '3564',
#   'Likes': '54',
#   'Comments': '5'},
#  {'Title': 'How to transform windows  7 to Linux Ubuntu',
#   'Published_date': '2015-07-19T08:00:00Z',
#   'Views': '1035',
#   'Likes': '21',
#   'Comments': '11'},
#  {'Title': 'How to transform windows  7 to Android Kitkat',
#   'Published_date': '2015-07-18T08:00:00Z',
#   'Views': '1061',
#   'Likes': '38',
#   'Comments': '17'},
#  {'Title': 'How to transform windows  7 to Mountain Lion',
#   'Published_date': '2015-07-17T08:00:01Z',
#   'Views': '825',
#   'Likes': '39',
#   'Comments': '12'},
#  {'Title': 'Unboxing Riflettori luce',
#   'Published_date': '2015-07-16T14:00:02Z',
#   'Views': '836',
#   'Likes': '46',
#   'Comments': '8'},
#  {'Title': 'Come comandare il mouse con la webcam con Gabby16bit',
#   'Published_date': '2015-07-14T14:00:03Z',
#   'Views': '4466',
#   'Likes': '210',
#   'Comments': '35'},
#  {'Title': 'Come avviare Windows 7 e 8 1 in modalità provvisoria con Thekingzela',
#   'Published_date': '2015-07-13T14:00:00Z',
#   'Views': '80318',
#   'Likes': '557',
#   'Comments': '60'},
#  {'Title': 'Unboxing Penna usb digitale terrestre, USB DVB T',
#   'Published_date': '2015-07-09T14:00:04Z',
#   'Views': '11184',
#   'Likes': '80',
#   'Comments': '13'},
#  {'Title': 'Come aggiornare i firmware di una Canon con NYKK3',
#   'Published_date': '2015-07-09T14:00:00Z',
#   'Views': '4565',
#   'Likes': '83',
#   'Comments': '12'},
#  {'Title': 'Unboxing Obbiettivo Canon EF 50mm 1.8 II',
#   'Published_date': '2015-07-02T14:00:00Z',
#   'Views': '864',
#   'Likes': '38',
#   'Comments': '18'},
#  {'Title': 'Monitor 7 pollici, Lilliput 668GL',
#   'Published_date': '2015-06-25T14:00:01Z',
#   'Views': '3520',
#   'Likes': '75',
#   'Comments': '18'},
#  {'Title': 'Trasformare Windows 7 in XP',
#   'Published_date': '2015-06-24T12:00:00Z',
#   'Views': '4502',
#   'Likes': '110',
#   'Comments': '26'},
#  {'Title': 'vishius17 "L\'informatica papale papale"',
#   'Published_date': '2015-06-19T14:00:04Z',
#   'Views': '24902',
#   'Likes': '276',
#   'Comments': '40'},
#  {'Title': 'Unboxing Lexar Professional 32GB Class 10 UHS 1 600X, ITA',
#   'Published_date': '2015-06-18T14:00:01Z',
#   'Views': '926',
#   'Likes': '37',
#   'Comments': '10'},
#  {'Title': 'Trasformare Windows 7 in Vista',
#   'Published_date': '2015-06-17T12:00:00Z',
#   'Views': '2147',
#   'Likes': '76',
#   'Comments': '27'},
#  {'Title': 'Come aumentare le visualizzazioni su youtube',
#   'Published_date': '2015-06-16T15:00:00Z',
#   'Views': '10261',
#   'Likes': '504',
#   'Comments': '155'},
#  {'Title': 'Unboxing impugnatura per polso, Opteka GS 3',
#   'Published_date': '2015-06-11T14:00:00Z',
#   'Views': '1037',
#   'Likes': '39',
#   'Comments': '6'},
#  {'Title': 'Trasformare Windows 7 in Metro',
#   'Published_date': '2015-06-10T12:00:00Z',
#   'Views': '2324',
#   'Likes': '73',
#   'Comments': '18'},
#  {'Title': 'VIDEO TAG #2, JUST DO IT 10',
#   'Published_date': '2015-06-09T14:00:03Z',
#   'Views': '497',
#   'Likes': '38',
#   'Comments': '12'},
#  {'Title': 'Come convertire un video con Adobe Encoder feat Bear MCx Gaming',
#   'Published_date': '2015-06-08T14:00:01Z',
#   'Views': '953',
#   'Likes': '45',
#   'Comments': '7'},
#  {'Title': 'VIDEO TAG #1',
#   'Published_date': '2015-06-05T14:00:01Z',
#   'Views': '898',
#   'Likes': '69',
#   'Comments': '26'},
#  {'Title': 'Come renderizzare più progetti con Sony Vegas feat  Poketonx',
#   'Published_date': '2015-06-04T14:30:00Z',
#   'Views': '1366',
#   'Likes': '84',
#   'Comments': '13'},
#  {'Title': 'Unboxing Hamlet XDVDIAPO, lettore di diapositive e pellicole',
#   'Published_date': '2015-06-04T14:00:01Z',
#   'Views': '15221',
#   'Likes': '104',
#   'Comments': '14'},
#  {'Title': 'Trasformare Windows 7 in Blue Alienware',
#   'Published_date': '2015-06-03T12:00:01Z',
#   'Views': '2475',
#   'Likes': '60',
#   'Comments': '38'},
#  {'Title': 'Come dividere un file con FalCrow Production',
#   'Published_date': '2015-06-01T15:00:01Z',
#   'Views': '1077',
#   'Likes': '78',
#   'Comments': '38'},
#  {'Title': 'Unboxing Faro a led, Godox Led 308C',
#   'Published_date': '2015-05-28T14:00:01Z',
#   'Views': '9283',
#   'Likes': '48',
#   'Comments': '17'},
#  {'Title': 'Come trovare pixel bruciati con DorianBe',
#   'Published_date': '2015-05-27T15:00:01Z',
#   'Views': '17061',
#   'Likes': '264',
#   'Comments': '59'},
#  {'Title': 'Trasformare Windows 7 in Red Alienware',
#   'Published_date': '2015-05-26T12:00:05Z',
#   'Views': '2271',
#   'Likes': '82',
#   'Comments': '42'},
#  {'Title': 'Unboxing Cover fotocamera canon 6D',
#   'Published_date': '2015-05-21T14:00:04Z',
#   'Views': '741',
#   'Likes': '41',
#   'Comments': '14'},
#  {'Title': 'Trasformare Windows 7 in Green Alienware',
#   'Published_date': '2015-05-19T12:00:00Z',
#   'Views': '2941',
#   'Likes': '84',
#   'Comments': '63'},
#  {'Title': 'CONSIGLI SULLE BATTERIE',
#   'Published_date': '2015-05-15T14:00:00Z',
#   'Views': '2134',
#   'Likes': '112',
#   'Comments': '18'},
#  {'Title': 'Unboxing ChiliPower Canon LP E6 Kit da 1850mAh',
#   'Published_date': '2015-05-14T14:00:00Z',
#   'Views': '759',
#   'Likes': '22',
#   'Comments': '13'},
#  {'Title': 'Unboxing AVerMedia Live Gamer Portable,  C875 LGP',
#   'Published_date': '2015-05-09T14:00:01Z',
#   'Views': '1000',
#   'Likes': '47',
#   'Comments': '15'},
#  {'Title': 'I contro, AVerMedia Live Gamer Portable  C875 LGP',
#   'Published_date': '2015-05-08T12:00:01Z',
#   'Views': '876',
#   'Likes': '37',
#   'Comments': '9'},
#  {'Title': 'Trasformare Windows 7 in Angry Birds Space Game',
#   'Published_date': '2015-05-05T12:00:01Z',
#   'Views': '1642',
#   'Likes': '38',
#   'Comments': '15'},
#  {'Title': 'Unboxing Borsa porta fotocamera',
#   'Published_date': '2015-05-02T13:11:03Z',
#   'Views': '599',
#   'Likes': '12',
#   'Comments': '3'},
#  {'Title': 'Unboxing  Kit softbox',
#   'Published_date': '2015-04-30T17:18:33Z',
#   'Views': '1572',
#   'Likes': '85',
#   'Comments': '26'},
#  {'Title': 'Trasformare Windows 7 in Angry Birds Rio Game',
#   'Published_date': '2015-04-28T12:00:01Z',
#   'Views': '2546',
#   'Likes': '73',
#   'Comments': '8'},
#  {'Title': 'STAFFA A V',
#   'Published_date': '2015-04-23T12:56:35Z',
#   'Views': '1083',
#   'Likes': '60',
#   'Comments': '4'},
#  {'Title': 'POST-UNBOXING CANON 6D',
#   'Published_date': '2015-04-16T15:19:42Z',
#   'Views': '1259',
#   'Likes': '83',
#   'Comments': '20'},
#  {'Title': 'Bloopers #1',
#   'Published_date': '2015-02-10T15:00:00Z',
#   'Views': '2120',
#   'Likes': '109',
#   'Comments': '47'},
#  {'Title': 'SPECIALE 9000 ISCRITTI',
#   'Published_date': '2014-12-25T09:00:04Z',
#   'Views': '3668',
#   'Likes': '151',
#   'Comments': '81'},
#  {'Title': 'Trasformare Windows 7 in Mac OS X Orange',
#   'Published_date': '2014-11-23T13:30:02Z',
#   'Views': '4684',
#   'Likes': '74',
#   'Comments': '65'},
#  {'Title': 'Trasformare Windows 7 in Windows 8 Prototipo',
#   'Published_date': '2014-11-22T15:00:14Z',
#   'Views': '5333',
#   'Likes': '104',
#   'Comments': '29'},
#  {'Title': 'Trasformare Windows 7 in Mac OS X Gold',
#   'Published_date': '2014-11-21T15:00:08Z',
#   'Views': '6254',
#   'Likes': '149',
#   'Comments': '46'},
#  {'Title': 'Trasformare Windows 7 in Snow Leopard',
#   'Published_date': '2014-11-20T15:00:15Z',
#   'Views': '3549',
#   'Likes': '59',
#   'Comments': '26'},
#  {'Title': 'Trasformare Windows 7 in Angry Birds StarWars Game',
#   'Published_date': '2014-11-19T15:00:11Z',
#   'Views': '1790',
#   'Likes': '56',
#   'Comments': '21'},
#  {'Title': 'Trasformare Windows 7 in Mac OS X',
#   'Published_date': '2014-11-18T15:00:07Z',
#   'Views': '9932',
#   'Likes': '134',
#   'Comments': '80'},
#  {'Title': 'Trasformare Windows 7 in Xbox',
#   'Published_date': '2014-11-16T15:00:05Z',
#   'Views': '5533',
#   'Likes': '131',
#   'Comments': '36'},
#  {'Title': 'Trasformare Windows 7 in Linux Gnome',
#   'Published_date': '2014-11-15T15:00:01Z',
#   'Views': '1725',
#   'Likes': '47',
#   'Comments': '9'},
#  {'Title': 'Trasformare Windows 7 in Linux Ubuntu',
#   'Published_date': '2014-11-14T15:00:10Z',
#   'Views': '2635',
#   'Likes': '53',
#   'Comments': '29'},
#  {'Title': 'Trasformare Windows 7 in iOS 7',
#   'Published_date': '2014-11-13T15:00:05Z',
#   'Views': '2978',
#   'Likes': '73',
#   'Comments': '46'},
#  {'Title': 'Trasformare Windows 7 in Android Kitkat',
#   'Published_date': '2014-11-12T15:00:16Z',
#   'Views': '4602',
#   'Likes': '88',
#   'Comments': '24'},
#  {'Title': 'Trasformare Windows 7 in Mountain Lion',
#   'Published_date': '2014-11-11T15:00:07Z',
#   'Views': '3260',
#   'Likes': '112',
#   'Comments': '70'},
#  {'Title': 'Io ho tornato',
#   'Published_date': '2014-11-05T21:01:34Z',
#   'Views': '1766',
#   'Likes': '92',
#   'Comments': '34'},
#  {'Title': 'Estrazione contest Emisoft',
#   'Published_date': '2014-11-01T16:08:08Z',
#   'Views': '668',
#   'Likes': '22',
#   'Comments': '18'},
#  {'Title': 'Come diventare uno Youtuber gamer, consigli',
#   'Published_date': '2014-10-29T15:00:15Z',
#   'Views': '4620',
#   'Likes': '180',
#   'Comments': '26'},
#  {'Title': 'Unboxing Hard disk esterno WD Elements',
#   'Published_date': '2014-10-23T14:00:05Z',
#   'Views': '1933',
#   'Likes': '78',
#   'Comments': '17'},
#  {'Title': 'Paga caro e stai bene, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-10-22T14:00:14Z',
#   'Views': '2893',
#   'Likes': '151',
#   'Comments': '35'},
#  {'Title': 'Consigli anti copyright per youtuber gamers, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-10-15T14:00:10Z',
#   'Views': '1857',
#   'Likes': '70',
#   'Comments': '9'},
#  {'Title': 'Scaricare file  dll con Violetta Rocks',
#   'Published_date': '2014-10-14T14:00:09Z',
#   'Views': '2074',
#   'Likes': '58',
#   'Comments': '5'},
#  {'Title': 'Contest Emsisoft',
#   'Published_date': '2014-10-10T14:51:36Z',
#   'Views': '889',
#   'Likes': '57',
#   'Comments': '22'},
#  {'Title': 'Emsisoft Anti-Malware, un factotum da guerra',
#   'Published_date': '2014-10-10T14:48:41Z',
#   'Views': '1049',
#   'Likes': '47',
#   'Comments': '14'},
#  {'Title': 'Come cambiare la RAM, Asus Eee PC 1000HD',
#   'Published_date': '2014-10-09T14:00:08Z',
#   'Views': '3211',
#   'Likes': '60',
#   'Comments': '18'},
#  {'Title': 'Come fare live streaming su Youtube, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-10-08T14:00:14Z',
#   'Views': '16084',
#   'Likes': '302',
#   'Comments': '51'},
#  {'Title': 'Come cambiare un Hard Disk, Asus Eee PC 1000HD',
#   'Published_date': '2014-10-02T14:00:08Z',
#   'Views': '3378',
#   'Likes': '49',
#   'Comments': '29'},
#  {'Title': 'Come fare live streaming su Twitch, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-10-01T14:01:20Z',
#   'Views': '59098',
#   'Likes': '674',
#   'Comments': '112'},
#  {'Title': 'Modificare una webcam per treppiede',
#   'Published_date': '2014-09-25T14:00:08Z',
#   'Views': '1730',
#   'Likes': '43',
#   'Comments': '11'},
#  {'Title': 'Come esportare un gameplay, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-09-24T04:00:02Z',
#   'Views': '1008',
#   'Likes': '39',
#   'Comments': '13'},
#  {'Title': 'Computer o console, dove giocare',
#   'Published_date': '2014-09-19T14:00:09Z',
#   'Views': '5955',
#   'Likes': '412',
#   'Comments': '145'},
#  {'Title': 'Creare gameplay con più webcam, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-09-17T14:00:06Z',
#   'Views': '1349',
#   'Likes': '68',
#   'Comments': '21'},
#  {'Title': 'Importazione ed esportazione di Preset Adobe CS6, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-09-10T14:00:15Z',
#   'Views': '730',
#   'Likes': '23',
#   'Comments': '5'},
#  {'Title': 'Come scaricare a 20 MB',
#   'Published_date': '2014-09-09T14:00:06Z',
#   'Views': '72493',
#   'Likes': '1029',
#   'Comments': '242'},
#  {'Title': 'Download crack, 100% funzionante',
#   'Published_date': '2014-09-05T14:00:04Z',
#   'Views': '7103',
#   'Likes': '258',
#   'Comments': '109'},
#  {'Title': 'Come scaricare software e giochi da torrent ed Emule',
#   'Published_date': '2014-09-05T14:00:02Z',
#   'Views': '6860',
#   'Likes': '225',
#   'Comments': '61'},
#  {'Title': 'Creazione di Preset su Premiere CS6, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-09-03T14:00:03Z',
#   'Views': '1215',
#   'Likes': '45',
#   'Comments': '17'},
#  {'Title': 'Come eliminare i lag nei giochi, Aumentare gli fps',
#   'Published_date': '2014-09-02T14:00:04Z',
#   'Views': '111472',
#   'Likes': '1817',
#   'Comments': '597'},
#  {'Title': 'Creazione della vignetta su webcam e barra sponsor, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-08-27T14:00:04Z',
#   'Views': '1904',
#   'Likes': '97',
#   'Comments': '40'},
#  {'Title': 'Correzione colore ed equalizzatore audio, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-08-20T14:00:07Z',
#   'Views': '1305',
#   'Likes': '58',
#   'Comments': '21'},
#  {'Title': 'Sincronizzare cartelle tra 2 pc con Mega, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-08-13T14:00:06Z',
#   'Views': '2913',
#   'Likes': '39',
#   'Comments': '20'},
#  {'Title': 'Sincronizzare cartelle tra 2 pc con Google Drive, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-08-06T14:00:08Z',
#   'Views': '9718',
#   'Likes': '68',
#   'Comments': '17'},
#  {'Title': 'Spese da affrontare, Diventare uno Youtubers gamer, intermedio',
#   'Published_date': '2014-08-05T14:00:08Z',
#   'Views': '3876',
#   'Likes': '191',
#   'Comments': '66'},
#  {'Title': 'Come montare video per gameplay avanzati, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-07-30T14:00:09Z',
#   'Views': '11574',
#   'Likes': '255',
#   'Comments': '45'},
#  {'Title': 'Come fare live streaming su Youtube, Diventare uno Youtubers gamer, intermedio',
#   'Published_date': '2014-07-29T14:00:07Z',
#   'Views': '6577',
#   'Likes': '180',
#   'Comments': '34'},
#  {'Title': 'Tutorial Iobit Unistaller con Nerd Attack TV',
#   'Published_date': '2014-07-28T14:00:08Z',
#   'Views': '1988',
#   'Likes': '90',
#   'Comments': '38'},
#  {'Title': 'Creare effetto radiofonico sul microfono, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-07-23T14:00:06Z',
#   'Views': '7926',
#   'Likes': '116',
#   'Comments': '42'},
#  {'Title': 'Come fare live streaming su Twitch, Diventare uno Youtubers gamer, intermedio',
#   'Published_date': '2014-07-22T14:00:06Z',
#   'Views': '2464',
#   'Likes': '74',
#   'Comments': '33'},
#  {'Title': 'Tutorial Game Booster con Matcha Latte Vlog',
#   'Published_date': '2014-07-19T14:00:05Z',
#   'Views': '4225',
#   'Likes': '133',
#   'Comments': '34'},
#  {'Title': 'Come monitorare il sistema con Golden Gianpy',
#   'Published_date': '2014-07-18T14:00:05Z',
#   'Views': '6639',
#   'Likes': '166',
#   'Comments': '36'},
#  {'Title': 'Come montare gameplay, Diventare uno Youtubers gamer, Metodo alternativo',
#   'Published_date': '2014-07-17T14:00:05Z',
#   'Views': '2137',
#   'Likes': '52',
#   'Comments': '13'},
#  {'Title': 'Come registrare da una webcam o 2 webcam, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-07-16T14:00:06Z',
#   'Views': '10179',
#   'Likes': '152',
#   'Comments': '17'},
#  {'Title': 'Montare ed esportare con Sony Vegas, Diventare uno Youtubers gamer, intermedio',
#   'Published_date': '2014-07-15T14:30:01Z',
#   'Views': '3806',
#   'Likes': '118',
#   'Comments': '28'},
#  {'Title': 'Come installare un gruppo programmi con una operazione con Mikeshowsha',
#   'Published_date': '2014-07-11T14:00:05Z',
#   'Views': '2742',
#   'Likes': '120',
#   'Comments': '14'},
#  {'Title': 'Come non farsi beccare dal copyright, Diventare uno Youtubers gamer, Metodo alternativo',
#   'Published_date': '2014-07-10T14:00:05Z',
#   'Views': '9230',
#   'Likes': '251',
#   'Comments': '46'},
#  {'Title': 'Come registrare gameplay con Dxtory e codec, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-07-09T14:00:04Z',
#   'Views': '8586',
#   'Likes': '185',
#   'Comments': '30'},
#  {'Title': 'Come registrare i gameplay con webcam, Diventare uno Youtubers gamer, intermedio',
#   'Published_date': '2014-07-08T14:00:05Z',
#   'Views': '88373',
#   'Likes': '1487',
#   'Comments': '274'},
#  {'Title': 'Attrezzatura e spese, Diventare uno Youtubers gamer, Semplice',
#   'Published_date': '2014-07-07T14:00:06Z',
#   'Views': '7879',
#   'Likes': '276',
#   'Comments': '29'},
#  {'Title': 'Un segugio infallibile, Desktop Search con MrSimonoh',
#   'Published_date': '2014-07-04T14:00:06Z',
#   'Views': '1132',
#   'Likes': '48',
#   'Comments': '17'},
#  {'Title': 'Come registrare con Xsplit, Diventare uno Youtubers gamer, Metodo alternativo',
#   'Published_date': '2014-07-03T05:30:00Z',
#   'Views': '13601',
#   'Likes': '233',
#   'Comments': '114'},
#  {'Title': 'Aprire le porte del router, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-07-02T14:00:06Z',
#   'Views': '2850',
#   'Likes': '115',
#   'Comments': '10'},
#  {'Title': 'Aprire le porte del router, Diventare uno Youtubers gamer, intermedio',
#   'Published_date': '2014-07-01T14:00:04Z',
#   'Views': '2436',
#   'Likes': '70',
#   'Comments': '12'},
#  {'Title': 'Montare ed esportare con Movie Maker, Diventare uno Youtubers gamer, Semplice',
#   'Published_date': '2014-06-30T14:00:04Z',
#   'Views': '45806',
#   'Likes': '499',
#   'Comments': '149'},
#  {'Title': 'Come aumentare iscritti e visualizzazioni con vishius17',
#   'Published_date': '2014-06-28T14:00:03Z',
#   'Views': '20316',
#   'Likes': '678',
#   'Comments': '158'},
#  {'Title': 'Unico programma per aprire tanti i file con Redez di QDSS',
#   'Published_date': '2014-06-27T14:00:04Z',
#   'Views': '13553',
#   'Likes': '342',
#   'Comments': '63'},
#  {'Title': 'Settaggi e altro, Diventare uno Youtubers gamer, Metodo alternativo',
#   'Published_date': '2014-06-26T14:00:07Z',
#   'Views': '1137',
#   'Likes': '59',
#   'Comments': '5'},
#  {'Title': 'Come settare al meglio il PC, Diventare uno Youtubers gamer, Avanzato',
#   'Published_date': '2014-06-25T14:00:05Z',
#   'Views': '4525',
#   'Likes': '141',
#   'Comments': '14'},
#  {'Title': 'Settaggi PC, Diventare uno Youtubers gamer, intermedio',
#   'Published_date': '2014-06-24T14:00:06Z',
#   'Views': '3876',
#   'Likes': '141',
#   'Comments': '30'},
#  {'Title': 'Registrare con fraps, Diventare uno Youtubers gamer, Semplice',
#   'Published_date': '2014-06-23T14:00:05Z',
#   'Views': '37397',
#   'Likes': '684',
#   'Comments': '160'},
#  {'Title': 'Come rimuovere rumore di sottofondo con Jasonrdr',
#   'Published_date': '2014-06-22T14:00:05Z',
#   'Views': '7658',
#   'Likes': '121',
#   'Comments': '51'},
#  {'Title': 'Io non creo...aiuto e consiglio!',
#   'Published_date': '2014-06-22T07:00:01Z',
#   'Views': '507',
#   'Likes': '51',
#   'Comments': '22'},
#  {'Title': 'Come cancellare definitivamente dei file con Stevepanda',
#   'Published_date': '2014-06-21T14:00:05Z',
#   'Views': '3573',
#   'Likes': '58',
#   'Comments': '16'},
#  {'Title': 'Guida come fare lo Youtuber Gamer, Metodo alternativo',
#   'Published_date': '2014-06-20T14:55:16Z',
#   'Views': '2862',
#   'Likes': '138',
#   'Comments': '20'},
#  {'Title': 'Come diventare uno Youtuber gamer Avanzato',
#   'Published_date': '2014-06-19T14:00:05Z',
#   'Views': '5873',
#   'Likes': '238',
#   'Comments': '32'},
#  {'Title': 'Diventare uno Youtubers gamer, intermedio, premessa',
#   'Published_date': '2014-06-18T14:00:06Z',
#   'Views': '4484',
#   'Likes': '118',
#   'Comments': '30'},
#  {'Title': 'Fare lo Youtubers gamer, Semplice, Premessa',
#   'Published_date': '2014-06-17T14:00:05Z',
#   'Views': '7394',
#   'Likes': '310',
#   'Comments': '22'},
#  {'Title': 'Come diventare uno Youtuber gamer',
#   'Published_date': '2014-06-16T14:00:06Z',
#   'Views': '20986',
#   'Likes': '944',
#   'Comments': '54'},
#  {'Title': 'Prossimamente, Come diventare uno Youtuber Gamer',
#   'Published_date': '2014-06-09T14:00:05Z',
#   'Views': '454',
#   'Likes': '40',
#   'Comments': '22'},
#  {'Title': 'Come masterizzare, creare, montare immagini file .iso con Riparare low cost',
#   'Published_date': '2014-04-16T06:00:01Z',
#   'Views': '12470',
#   'Likes': '92',
#   'Comments': '73'},
#  {'Title': 'Analizzare lo spazio sul pc con Dr. Game',
#   'Published_date': '2014-04-09T06:00:01Z',
#   'Views': '2430',
#   'Likes': '72',
#   'Comments': '23'},
#  {'Title': 'Come spammare un hangout',
#   'Published_date': '2014-04-08T06:00:01Z',
#   'Views': '1098',
#   'Likes': '24',
#   'Comments': '4'},
#  {'Title': 'Come correggere gli errori di un hard disk',
#   'Published_date': '2014-04-01T06:00:01Z',
#   'Views': '28884',
#   'Likes': '318',
#   'Comments': '87'},
#  {'Title': 'Desktop a 360 gradi e Desktop slider con Giacomo Citro',
#   'Published_date': '2014-04-01T06:00:00Z',
#   'Views': '1643',
#   'Likes': '53',
#   'Comments': '7'},
#  {'Title': 'Come equalizzare mp3',
#   'Published_date': '2014-03-29T07:00:01Z',
#   'Views': '2555',
#   'Likes': '35',
#   'Comments': '5'},
#  {'Title': 'Come aggiornare i programmi sul pc',
#   'Published_date': '2014-03-25T07:00:01Z',
#   'Views': '6957',
#   'Likes': '127',
#   'Comments': '14'},
#  {'Title': 'Come testare un hard disk',
#   'Published_date': '2014-03-22T07:00:01Z',
#   'Views': '8095',
#   'Likes': '67',
#   'Comments': '14'},
#  {'Title': 'Come aggiornare i driver del computer',
#   'Published_date': '2014-03-18T07:00:01Z',
#   'Views': '36091',
#   'Likes': '564',
#   'Comments': '172'},
#  {'Title': 'Equalizzare una canzone con audacity',
#   'Published_date': '2014-03-15T07:00:01Z',
#   'Views': '26086',
#   'Likes': '166',
#   'Comments': '45'},
#  {'Title': 'Riconoscimento facciale',
#   'Published_date': '2014-03-11T07:00:01Z',
#   'Views': '5481',
#   'Likes': '72',
#   'Comments': '13'},
#  {'Title': 'Trucchi per Windows',
#   'Published_date': '2014-03-09T07:00:01Z',
#   'Views': '3135',
#   'Likes': '68',
#   'Comments': '20'},
#  {'Title': 'Come ripristinare Windows 7 e 8',
#   'Published_date': '2014-03-08T07:00:00Z',
#   'Views': '271309',
#   'Likes': '3032',
#   'Comments': '227'},
#  {'Title': 'Il miglior firewall',
#   'Published_date': '2014-03-04T07:00:00Z',
#   'Views': '2197',
#   'Likes': '50',
#   'Comments': '15'},
#  {'Title': 'Auto mouse con Alberto Pagnotta',
#   'Published_date': '2014-03-03T07:00:02Z',
#   'Views': '2737',
#   'Likes': '87',
#   'Comments': '12'},
#  {'Title': 'Come velocizzare Windows Vista',
#   'Published_date': '2014-03-02T07:00:01Z',
#   'Views': '3742',
#   'Likes': '52',
#   'Comments': '11'},
#  {'Title': 'Come nascondere una cartella',
#   'Published_date': '2014-03-01T07:00:01Z',
#   'Views': '8823',
#   'Likes': '105',
#   'Comments': '14'},
#  {'Title': 'Come mettere il pulsante start in windows 8 e 8.1 con Edie Didi',
#   'Published_date': '2014-02-28T07:00:01Z',
#   'Views': '33949',
#   'Likes': '390',
#   'Comments': '163'},
#  {'Title': 'Il miglior antivirus',
#   'Published_date': '2014-02-25T07:00:01Z',
#   'Views': '17072',
#   'Likes': '258',
#   'Comments': '67'},
#  {'Title': 'Come velocizzare Windows 8 e 8.1',
#   'Published_date': '2014-02-23T07:00:01Z',
#   'Views': '10634',
#   'Likes': '205',
#   'Comments': '6'},
#  {'Title': 'Come gestire i nostri account social network',
#   'Published_date': '2014-02-22T07:00:00Z',
#   'Views': '718',
#   'Likes': '18',
#   'Comments': '4'},
#  {'Title': 'Joypad Logitech F310, Unboxing, ita',
#   'Published_date': '2014-02-20T07:00:01Z',
#   'Views': '3912',
#   'Likes': '64',
#   'Comments': '19'},
#  {'Title': 'Il miglior antispam',
#   'Published_date': '2014-02-18T07:00:00Z',
#   'Views': '1869',
#   'Likes': '35',
#   'Comments': '5'},
#  {'Title': 'Come velocizzare Windows 7',
#   'Published_date': '2014-02-16T07:00:01Z',
#   'Views': '4409',
#   'Likes': '106',
#   'Comments': '20'},
#  {'Title': 'Come creare una partizione',
#   'Published_date': '2014-02-15T07:00:01Z',
#   'Views': '8318',
#   'Likes': '71',
#   'Comments': '43'},
#  {'Title': 'Cuffie Ozone ST Unboxing',
#   'Published_date': '2014-02-13T07:00:00Z',
#   'Views': '802',
#   'Likes': '35',
#   'Comments': '18'},
#  {'Title': 'Come formattare un pc e installare Windows 2000',
#   'Published_date': '2014-02-12T07:00:01Z',
#   'Views': '7597',
#   'Likes': '159',
#   'Comments': '22'},
#  {'Title': 'Il miglior Anti Rootkit',
#   'Published_date': '2014-02-11T07:00:01Z',
#   'Views': '917',
#   'Likes': '23',
#   'Comments': '8'},
#  {'Title': 'Vishius17 "L\'informatica papale papale" - 2014',
#   'Published_date': '2014-02-09T07:00:01Z',
#   'Views': '17991',
#   'Likes': '79',
#   'Comments': '28'},
#  {'Title': 'Come controllare tutti i social network',
#   'Published_date': '2014-02-08T07:00:01Z',
#   'Views': '577',
#   'Likes': '15',
#   'Comments': '4'},
#  {'Title': 'Come cambiare una scheda video',
#   'Published_date': '2014-02-06T10:00:02Z',
#   'Views': '7306',
#   'Likes': '188',
#   'Comments': '27'},
#  {'Title': 'Come formattare un pc e installare Xubuntu',
#   'Published_date': '2014-02-05T07:00:01Z',
#   'Views': '15116',
#   'Likes': '87',
#   'Comments': '49'},
#  {'Title': 'Come usare le app di Android sul pc',
#   'Published_date': '2014-02-04T07:00:01Z',
#   'Views': '17808',
#   'Likes': '231',
#   'Comments': '60'},
#  {'Title': 'Asta di beneficenza feat wolf 91',
#   'Published_date': '2014-02-03T16:38:50Z',
#   'Views': '210',
#   'Likes': '5',
#   'Comments': '1'},
#  {'Title': 'Asta di beneficenza feat vishius17',
#   'Published_date': '2014-02-02T12:49:17Z',
#   'Views': '380',
#   'Likes': '23',
#   'Comments': '2'},
#  {'Title': 'Come capire quali componenti ci sono nel computer',
#   'Published_date': '2014-02-01T07:00:00Z',
#   'Views': '1314',
#   'Likes': '58',
#   'Comments': '26'},
#  {'Title': "Come cambiare l'alimentatore di un computer",
#   'Published_date': '2014-01-30T10:00:01Z',
#   'Views': '1611',
#   'Likes': '21',
#   'Comments': '15'},
#  {'Title': 'Come formattare un pc e installare Kubuntu',
#   'Published_date': '2014-01-29T07:00:01Z',
#   'Views': '3112',
#   'Likes': '69',
#   'Comments': '14'},
#  {'Title': 'Come usare Android sul pc',
#   'Published_date': '2014-01-28T07:00:01Z',
#   'Views': '26514',
#   'Likes': '698',
#   'Comments': '139'},
#  {'Title': 'Come mettere una password ad una cartella',
#   'Published_date': '2014-01-25T07:00:01Z',
#   'Views': '72674',
#   'Likes': '517',
#   'Comments': '139'},
#  {'Title': 'Come cambiare dissipatore con uno a liquido',
#   'Published_date': '2014-01-23T08:00:01Z',
#   'Views': '6744',
#   'Likes': '81',
#   'Comments': '41'},
#  {'Title': 'Come formattare un pc e installare Ubuntu 13',
#   'Published_date': '2014-01-22T07:00:01Z',
#   'Views': '10174',
#   'Likes': '133',
#   'Comments': '23'},
#  {'Title': 'Come recuperare spazio sul proprio hard disk',
#   'Published_date': '2014-01-21T07:00:01Z',
#   'Views': '12058',
#   'Likes': '203',
#   'Comments': '53'},
#  {'Title': 'Come testare la velocità di un hard disk, benchmark hard disk',
#   'Published_date': '2014-01-18T07:00:00Z',
#   'Views': '11241',
#   'Likes': '164',
#   'Comments': '14'},
#  {'Title': 'Scheda madre AsRock H77 Pro4/MVP, Unboxing',
#   'Published_date': '2014-01-16T21:30:02Z',
#   'Views': '1217',
#   'Likes': '15',
#   'Comments': '11'},
#  {'Title': 'Come formattare un pc e installare Ubuntu 12',
#   'Published_date': '2014-01-15T07:00:00Z',
#   'Views': '4955',
#   'Likes': '44',
#   'Comments': '29'},
#  {'Title': 'Come recuperare file cancellati',
#   'Published_date': '2014-01-14T07:00:01Z',
#   'Views': '8155',
#   'Likes': '125',
#   'Comments': '34'},
#  {'Title': 'Cancellare ogni traccia di un software, Revo Unistaller',
#   'Published_date': '2014-01-10T23:49:19Z',
#   'Views': '4231',
#   'Likes': '51',
#   'Comments': '19'},
#  {'Title': 'Ram Corsair Vengeance Low Profile 8 GB RAM, Unboxing',
#   'Published_date': '2014-01-09T10:00:01Z',
#   'Views': '1202',
#   'Likes': '19',
#   'Comments': '7'},
#  {'Title': 'Come formattare un pc e installare Windows XP SP3',
#   'Published_date': '2014-01-08T07:00:01Z',
#   'Views': '75514',
#   'Likes': '399',
#   'Comments': '100'},
#  {'Title': 'Come creare una password sicura',
#   'Published_date': '2014-01-07T07:00:01Z',
#   'Views': '17491',
#   'Likes': '262',
#   'Comments': '38'},
#  {'Title': 'Estrazione contest Retro FPS',
#   'Published_date': '2014-01-03T05:30:09Z',
#   'Views': '313',
#   'Likes': '21',
#   'Comments': '9'},
#  {'Title': 'Nvidia GTX 760, GTX 760 DC2 OC 2GD5, UNBOXING ITA',
#   'Published_date': '2014-01-02T10:00:02Z',
#   'Views': '2510',
#   'Likes': '48',
#   'Comments': '31'},
#  {'Title': 'Come formattare un pc e installare Windows 7',
#   'Published_date': '2014-01-01T07:00:01Z',
#   'Views': '327049',
#   'Likes': '2325',
#   'Comments': '408'},
#  {'Title': 'Come avere il Nat aperto, come aprire il Nat',
#   'Published_date': '2013-12-31T07:00:00Z',
#   'Views': '47782',
#   'Likes': '373',
#   'Comments': '94'},
#  {'Title': 'Velocizzare il Pc, considerazioni finali, Part38, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-12-29T09:00:01Z',
#   'Views': '2469',
#   'Likes': '52',
#   'Comments': '27'},
#  {'Title': 'Aprire le porte del router per WebCam Monitor',
#   'Published_date': '2013-12-26T12:00:01Z',
#   'Views': '862',
#   'Likes': '1',
#   'Comments': '0'},
#  {'Title': 'Dissipatore H60 Corsair, Unboxing',
#   'Published_date': '2013-12-26T10:00:02Z',
#   'Views': '1955',
#   'Likes': '43',
#   'Comments': '24'},
#  {'Title': 'Aprire le porte del router per World of WarCraft [PC] #84',
#   'Published_date': '2013-12-25T12:00:03Z',
#   'Views': '662',
#   'Likes': '2',
#   'Comments': '0'},
#  {'Title': 'Come formattare un pc e installare Windows 8 e 8.1',
#   'Published_date': '2013-12-25T07:00:02Z',
#   'Views': '85617',
#   'Likes': '716',
#   'Comments': '124'},
#  {'Title': 'Aprire le porte del router per World of Tanks [PC] #83',
#   'Published_date': '2013-12-24T12:00:03Z',
#   'Views': '1191',
#   'Likes': '3',
#   'Comments': '0'},
#  {'Title': 'Come entrare nel bios',
#   'Published_date': '2013-12-24T07:00:01Z',
#   'Views': '238193',
#   'Likes': '1606',
#   'Comments': '307'},
#  {'Title': 'Aprire le porte del router per Wolfenstein Enemy Territory [PC] #82',
#   'Published_date': '2013-12-23T12:00:04Z',
#   'Views': '79',
#   'Likes': '0',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per Warcraft 3 [PC] #81',
#   'Published_date': '2013-12-22T12:00:02Z',
#   'Views': '312',
#   'Likes': '0',
#   'Comments': '0'},
#  {'Title': 'Le 16 cose da non fare al pc, Part37, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-12-21T15:00:04Z',
#   'Views': '13875',
#   'Likes': '200',
#   'Comments': '48'},
#  {'Title': 'Aprire le porte del router per Unreal Tournament 2004 [PC] #80',
#   'Published_date': '2013-12-21T12:00:08Z',
#   'Views': '98',
#   'Likes': '1',
#   'Comments': '1'},
#  {'Title': 'Aprire le porte del router per Unreal Tournament 3 [PC] #79',
#   'Published_date': '2013-12-20T12:00:02Z',
#   'Views': '142',
#   'Likes': '0',
#   'Comments': '1'},
#  {'Title': 'Aprire le porte del router per SWAT 3 [PC] #78',
#   'Published_date': '2013-12-19T12:00:03Z',
#   'Views': '69',
#   'Likes': '0',
#   'Comments': '0'},
#  {'Title': 'Come trattano i pacchi i corrieri',
#   'Published_date': '2013-12-19T10:00:02Z',
#   'Views': '20427',
#   'Likes': '207',
#   'Comments': '98'},
#  {'Title': 'Aprire le porte del router per Splinter Cell Conviction [PC] #77',
#   'Published_date': '2013-12-18T12:00:03Z',
#   'Views': '180',
#   'Likes': '1',
#   'Comments': '1'},
#  {'Title': 'Aprire le porte del router per Quake 4 [PC] #76',
#   'Published_date': '2013-12-17T12:00:03Z',
#   'Views': '73',
#   'Likes': '0',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per Quake 3 [PC] #75',
#   'Published_date': '2013-12-16T12:00:03Z',
#   'Views': '77',
#   'Likes': '2',
#   'Comments': '2'},
#  {'Title': 'Aprire le porte del router per Operation Flashpoint 2 Dragon Rising [PC] #74',
#   'Published_date': '2013-12-15T12:00:01Z',
#   'Views': '132',
#   'Likes': '0',
#   'Comments': '0'},
#  {'Title': 'Come velocizzare il computer velocemente, Part36, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-12-14T15:00:03Z',
#   'Views': '1887',
#   'Likes': '43',
#   'Comments': '18'},
#  {'Title': 'Aprire le porte del router per Max Payne 3 [PC] #72',
#   'Published_date': '2013-12-13T12:00:02Z',
#   'Views': '98',
#   'Likes': '1',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per Mass Effect 3 [PC] #71',
#   'Published_date': '2013-12-12T12:00:02Z',
#   'Views': '135',
#   'Likes': '0',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per Left 4 Dead 2 e 1 [PC] #70',
#   'Published_date': '2013-12-11T12:00:02Z',
#   'Views': '254',
#   'Likes': '2',
#   'Comments': '0'},
#  {'Title': 'Contest Retro FPS',
#   'Published_date': '2013-12-11T07:00:01Z',
#   'Views': '471',
#   'Likes': '15',
#   'Comments': '4'},
#  {'Title': 'Aprire le porte del router per Homefront [PC] #69',
#   'Published_date': '2013-12-10T12:00:02Z',
#   'Views': '54',
#   'Likes': '0',
#   'Comments': '0'},
#  {'Title': 'Alimentatore Silent Pro M850 Cooler master, Unboxing',
#   'Published_date': '2013-12-10T10:00:01Z',
#   'Views': '681',
#   'Likes': '15',
#   'Comments': '4'},
#  {'Title': 'Aprire le porte del router per Half Life 2 [PC] #68',
#   'Published_date': '2013-12-09T12:00:03Z',
#   'Views': '90',
#   'Likes': '2',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per Ghost Recon Future Soldier [PC] #67',
#   'Published_date': '2013-12-08T12:00:02Z',
#   'Views': '129',
#   'Likes': '1',
#   'Comments': '0'},
#  {'Title': 'Come usare oltre 3 Gb di RAM, Part35, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-12-07T15:00:02Z',
#   'Views': '9986',
#   'Likes': '94',
#   'Comments': '30'},
#  {'Title': 'Aprire le porte del router per Ghost Recon [PC] #66',
#   'Published_date': '2013-12-06T12:00:03Z',
#   'Views': '78',
#   'Likes': '1',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per FIFA 13 [PC] #65',
#   'Published_date': '2013-12-05T12:00:01Z',
#   'Views': '267',
#   'Likes': '2',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per Doom 3 [PC] #63',
#   'Published_date': '2013-12-03T12:00:01Z',
#   'Views': '69',
#   'Likes': '1',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per Diablo III [PC] #62',
#   'Published_date': '2013-12-02T12:00:02Z',
#   'Views': '268',
#   'Likes': '1',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per Diablo II [PC] #61',
#   'Published_date': '2013-12-01T12:00:02Z',
#   'Views': '77',
#   'Likes': '1',
#   'Comments': '0'},
#  {'Title': 'Cambiare Hard Disk con SSD, Part34, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-11-30T15:00:02Z',
#   'Views': '3527',
#   'Likes': '17',
#   'Comments': '6'},
#  {'Title': 'Aprire le porte del router per Diablo [PC] #60',
#   'Published_date': '2013-11-30T12:00:02Z',
#   'Views': '49',
#   'Likes': '0',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per Dead Space 3 [PC] #59',
#   'Published_date': '2013-11-29T12:00:02Z',
#   'Views': '586',
#   'Likes': '1',
#   'Comments': '3'},
#  {'Title': 'Aprire le porte del router per Dead Space 2 [PC] #58',
#   'Published_date': '2013-11-28T12:00:02Z',
#   'Views': '62',
#   'Likes': '0',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per Dead Island [PC] #57',
#   'Published_date': '2013-11-27T12:00:02Z',
#   'Views': '48',
#   'Likes': '2',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per DC Universe Online [PC] #56',
#   'Published_date': '2013-11-26T12:00:02Z',
#   'Views': '108',
#   'Likes': '0',
#   'Comments': '2'},
#  {'Title': 'Aprire le porte del router per Cube World [PC] #55',
#   'Published_date': '2013-11-25T12:00:02Z',
#   'Views': '55',
#   'Likes': '0',
#   'Comments': '0'},
#  {'Title': 'Aprire le porte del router per Crysis 3 [PC] #54',
#   'Published_date': '2013-11-24T12:00:02Z',
#   'Views': '228',
#   'Likes': '3',
#   'Comments': '0'},
#  {'Title': 'Quale alimentatore comprare, Part33, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-11-23T15:00:04Z',
#   'Views': '842',
#   'Likes': '15',
#   'Comments': '1'},
#  {'Title': 'Aprire le porte del router per Crysis 2 [PC] #53',
#   'Published_date': '2013-11-23T12:00:02Z',
#   'Views': '65',
#   'Likes': '0',
#   'Comments': '0'},
# ...
#   'Published_date': '2013-06-14T07:01:57Z',
#   'Views': '976',
#   'Likes': '31',
#   'Comments': '0'},
#  {'Title': 'Estrarre tracce audio da Dxtory, part17, Solo Gamer',
#   'Published_date': '2013-06-09T14:00:57Z',
#   'Views': '360',
#   'Likes': '8',
#   'Comments': '5'},
#  {'Title': 'Velocizzare SSD, Part9, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-06-08T14:00:25Z',
#   'Views': '2225',
#   'Likes': '26',
#   'Comments': '11'},
#  {'Title': 'Come fare un test della Memoria RAM con Memtest',
#   'Published_date': '2013-06-05T14:01:06Z',
#   'Views': '19744',
#   'Likes': '135',
#   'Comments': '16'},
#  {'Title': 'Codec Video e Audio per Dxtory, part 16, Solo Gamer',
#   'Published_date': '2013-06-02T14:00:17Z',
#   'Views': '1139',
#   'Likes': '20',
#   'Comments': '10'},
#  {'Title': 'Aumentare le dimensioni del buffer - Part8 [VELOCIZZARE IL PC ST.2]',
#   'Published_date': '2013-06-01T14:04:59Z',
#   'Views': '4384',
#   'Likes': '34',
#   'Comments': '20'},
#  {'Title': 'Stazione di gioco, Part15, Solo Gamer',
#   'Published_date': '2013-05-26T14:00:35Z',
#   'Views': '1258',
#   'Likes': '43',
#   'Comments': '4'},
#  {'Title': 'No deframmentazione e SSD, Part7, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-05-25T14:00:48Z',
#   'Views': '3363',
#   'Likes': '58',
#   'Comments': '6'},
#  {'Title': 'Migliorare le prestazioni del Computer e Internet, Part16, TURBO INTERNET',
#   'Published_date': '2013-05-24T14:01:00Z',
#   'Views': '2740',
#   'Likes': '34',
#   'Comments': '9'},
#  {'Title': 'Impostazioni di gioco per scheda grafiche Nvidia, Part14, Solo Gamer',
#   'Published_date': '2013-05-19T14:01:00Z',
#   'Views': '16297',
#   'Likes': '130',
#   'Comments': '24'},
#  {'Title': 'Più cache per File System NTFS, Part6, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-05-18T14:01:01Z',
#   'Views': '2312',
#   'Likes': '41',
#   'Comments': '12'},
#  {'Title': 'Overclocking e Controllo delle ventole, speed fan controll',
#   'Published_date': '2013-05-15T14:00:12Z',
#   'Views': '6007',
#   'Likes': '64',
#   'Comments': '15'},
#  {'Title': 'Game Booster e Recording Screen, Part13, Solo Gamer',
#   'Published_date': '2013-05-12T14:00:11Z',
#   'Views': '2471',
#   'Likes': '57',
#   'Comments': '22'},
#  {'Title': 'Aumentare prestazioni SSD, Part5, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-05-11T15:30:10Z',
#   'Views': '4217',
#   'Likes': '50',
#   'Comments': '8'},
#  {'Title': 'Windows sempre in Ram, Part4, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-05-11T14:00:10Z',
#   'Views': '3692',
#   'Likes': '55',
#   'Comments': '9'},
#  {'Title': 'Linux a portata di mano',
#   'Published_date': '2013-05-08T14:00:11Z',
#   'Views': '911',
#   'Likes': '34',
#   'Comments': '5'},
#  {'Title': 'Le domande stupide nel mondo dei PC - ReUP',
#   'Published_date': '2013-05-07T14:00:10Z',
#   'Views': '1038',
#   'Likes': '23',
#   'Comments': '2'},
#  {'Title': 'Tutorial Ezvid, Part12, Solo Gamer',
#   'Published_date': '2013-05-05T14:00:13Z',
#   'Views': '1889',
#   'Likes': '23',
#   'Comments': '13'},
#  {'Title': 'Disattivare indicizzazione, Part3, VELOCIZZARE IL PC, ST.2',
#   'Published_date': '2013-05-04T14:00:11Z',
#   'Views': '3745',
#   'Likes': '110',
#   'Comments': '27'},
#  {'Title': 'Le 12 cose fanno rallentare la connessione, Part15, TURBO INTERNET',
#   'Published_date': '2013-05-03T14:00:11Z',
#   'Views': '30660',
#   'Likes': '221',
#   'Comments': '23'},
#  {'Title': 'Fixit, il supporto della Microsoft',
#   'Published_date': '2013-05-01T14:00:23Z',
#   'Views': '487',
#   'Likes': '19',
#   'Comments': '5'},
#  {'Title': 'Ordinario giorno di assemblaggio',
#   'Published_date': '2013-04-30T14:00:22Z',
#   'Views': '2087',
#   'Likes': '68',
#   'Comments': '26'},
#  {'Title': 'Tutorial Dxtory, Part11, Solo Gamer',
#   'Published_date': '2013-04-28T14:00:23Z',
#   'Views': '660',
#   'Likes': '23',
#   'Comments': '9'},
#  {'Title': 'Velocizzare la chiusura di windows - Part2, VELOCIZZARE IL PC ST.2,',
#   'Published_date': '2013-04-27T14:00:23Z',
#   'Views': '5814',
#   'Likes': '168',
#   'Comments': '16'},
#  {'Title': 'Chiudere programmi che consumano internet, Part14, TURBO INTERNET',
#   'Published_date': '2013-04-26T15:30:19Z',
#   'Views': '3657',
#   'Likes': '47',
#   'Comments': '12'},
#  {'Title': 'Tutorial Fraps, Part10, Solo Gamer',
#   'Published_date': '2013-04-07T16:39:40Z',
#   'Views': '1052',
#   'Likes': '38',
#   'Comments': '21'},
#  {'Title': 'Usare tutti i Processori e Ram, Part1, VELOCIZZARE IL PC, ST.2,',
#   'Published_date': '2013-04-05T14:52:25Z',
#   'Views': '28901',
#   'Likes': '323',
#   'Comments': '115'},
#  {'Title': 'Chiavi cache, Part13, Turbo internet',
#   'Published_date': '2013-04-02T11:08:34Z',
#   'Views': '1210',
#   'Likes': '24',
#   'Comments': '5'},
#  {'Title': 'Modifica compound tcp, Part12, Turbo internet',
#   'Published_date': '2013-03-05T17:32:18Z',
#   'Views': '1754',
#   'Likes': '20',
#   'Comments': '3'},
#  {'Title': 'Conclusione - Part14 - [VELOCIZZARE IL PC]',
#   'Published_date': '2013-03-04T13:47:55Z',
#   'Views': '1773',
#   'Likes': '55',
#   'Comments': '25'},
#  {'Title': 'The best software - part13 - [BEST GRAFIC PC]',
#   'Published_date': '2013-02-28T14:17:23Z',
#   'Views': '900',
#   'Likes': '20',
#   'Comments': '4'},
#  {'Title': 'Più cache meno congestioni, Part11, Turbo internet',
#   'Published_date': '2013-02-26T16:31:55Z',
#   'Views': '1570',
#   'Likes': '30',
#   'Comments': '10'},
#  {'Title': 'Objectbar e Dockbar dei poveri, Part13, VELOCIZZARE IL PC',
#   'Published_date': '2013-02-25T16:59:28Z',
#   'Views': '2746',
#   'Likes': '49',
#   'Comments': '19'},
#  {'Title': 'Disattivare le funzionalità di Windows, Part12, VELOCIZZARE IL PC',
#   'Published_date': '2013-02-22T17:28:15Z',
#   'Views': '4869',
#   'Likes': '67',
#   'Comments': '17'},
#  {'Title': 'Cambiare le finestre - WindowBlinds - parte12 - [BEST GRAFIC PC]',
#   'Published_date': '2013-02-21T14:21:43Z',
#   'Views': '669',
#   'Likes': '11',
#   'Comments': '2'},
#  {'Title': 'Overclocking e Driver scheda video Nvidia, Part9, Solo Gamer',
#   'Published_date': '2013-02-20T14:52:01Z',
#   'Views': '4349',
#   'Likes': '76',
#   'Comments': '19'},
#  {'Title': 'Disabilitare registro TCP e Throttling, Part10, Turbo internet',
#   'Published_date': '2013-02-19T13:00:38Z',
#   'Views': '2193',
#   'Likes': '30',
#   'Comments': '4'},
#  {'Title': 'Sfondo logon - LogonStudio - parte11 - [BEST GRAFIC PC]',
#   'Published_date': '2013-02-14T15:27:58Z',
#   'Views': '591',
#   'Likes': '17',
#   'Comments': '0'},
#  {'Title': 'Overclocking e Driver scheda video ATI, Part8, Solo Gamer',
#   'Published_date': '2013-02-13T15:06:29Z',
#   'Views': '2684',
#   'Likes': '37',
#   'Comments': '4'},
#  {'Title': 'Puliamo il pc, Part9, Turbo internet',
#   'Published_date': '2013-02-12T15:42:42Z',
#   'Views': '7222',
#   'Likes': '105',
#   'Comments': '7'},
#  {'Title': 'Ripulire il menu, Part11, VELOCIZZARE IL PC',
#   'Published_date': '2013-02-11T16:50:53Z',
#   'Views': '4880',
#   'Likes': '79',
#   'Comments': '5'},
#  {'Title': 'Aggiornare i driver, Part7, Solo Gamer',
#   'Published_date': '2013-02-08T16:11:20Z',
#   'Views': '1897',
#   'Likes': '58',
#   'Comments': '20'},
#  {'Title': 'Finestre animate - Window FX - parte10 - [BEST GRAFIC PC]',
#   'Published_date': '2013-02-06T15:08:41Z',
#   'Views': '1327',
#   'Likes': '15',
#   'Comments': '3'},
#  {'Title': 'Ottimizzazione dei processori, Part7, Turbo internet',
#   'Published_date': '2013-02-05T15:11:24Z',
#   'Views': '2497',
#   'Likes': '36',
#   'Comments': '13'},
#  {'Title': 'Sfondo con video, Dream Scene - part3 - [BEST GRAFIC PC]',
#   'Published_date': '2013-02-05T08:47:37Z',
#   'Views': '560',
#   'Likes': '13',
#   'Comments': '5'},
#  {'Title': 'Aumentare le prestazioni di un pc V 2.0',
#   'Published_date': '2013-02-04T17:50:31Z',
#   'Views': '2504',
#   'Likes': '43',
#   'Comments': '6'},
#  {'Title': 'Tenere un pc pulito V 2.0, Ccleaner, malwarebyte, SUPERAntiSpyware',
#   'Published_date': '2013-02-04T17:49:50Z',
#   'Views': '22968',
#   'Likes': '280',
#   'Comments': '128'},
#  {'Title': "I criteri dell'hard disk, Part10, VELOCIZZARE IL PC",
#   'Published_date': '2013-02-03T14:56:27Z',
#   'Views': '6288',
#   'Likes': '89',
#   'Comments': '14'},
#  {'Title': 'Cambiare suoni di windows - SoundPackager - parte9 - [BEST GRAFIC PC]',
#   'Published_date': '2013-01-31T16:35:41Z',
#   'Views': '3330',
#   'Likes': '22',
#   'Comments': '6'},
#  {'Title': 'Meno Ping, Part5, Solo Gamer',
#   'Published_date': '2013-01-30T16:10:15Z',
#   'Views': '6815',
#   'Likes': '198',
#   'Comments': '70'},
#  {'Title': 'Disinstallare programmi inutili e UAC, Part9, VELOCIZZARE IL PC',
#   'Published_date': '2013-01-28T19:13:36Z',
#   'Views': '7326',
#   'Likes': '78',
#   'Comments': '18'},
#  {'Title': 'Sfondi animati - DeskScapes - parte8 - [BEST GRAFIC PC]',
#   'Published_date': '2013-01-24T10:33:04Z',
#   'Views': '2454',
#   'Likes': '28',
#   'Comments': '5'},
#  {'Title': 'Impostazioni di gioco, Part4, Solo Gamer',
#   'Published_date': '2013-01-23T19:19:06Z',
#   'Views': '2363',
#   'Likes': '82',
#   'Comments': '14'},
#  {'Title': 'Velocizzare Emule e Torrent, Part8, Turbo internet',
#   'Published_date': '2013-01-22T16:42:52Z',
#   'Views': '4669',
#   'Likes': '82',
#   'Comments': '34'},
#  {'Title': 'Mettiamo il boost, Part8, VELOCIZZARE IL PC',
#   'Published_date': '2013-01-21T18:01:03Z',
#   'Views': '6973',
#   'Likes': '99',
#   'Comments': '37'},
#  {'Title': 'Cambiare immagine boot - BootSkin - parte7 - [BEST GRAFIC PC]',
#   'Published_date': '2013-01-21T18:00:42Z',
#   'Views': '836',
#   'Likes': '11',
#   'Comments': '7'},
#  {'Title': 'Ordine sul desktop - Fences - parte6 - [BEST GRAFIC PC]',
#   'Published_date': '2013-01-18T15:59:24Z',
#   'Views': '1101',
#   'Likes': '17',
#   'Comments': '9'},
#  {'Title': "Disabilitare l'indicizazione, Part7, VELOCIZZARE IL PC",
#   'Published_date': '2013-01-14T17:03:46Z',
#   'Views': '5460',
#   'Likes': '71',
#   'Comments': '5'},
#  {'Title': 'Cursore - CursorFX In - parte5 - [BEST GRAFIC PC]',
#   'Published_date': '2013-01-11T14:54:39Z',
#   'Views': '897',
#   'Likes': '22',
#   'Comments': '7'},
#  {'Title': 'Chiudere processi internet, Part6, Turbo internet',
#   'Published_date': '2013-01-08T15:12:45Z',
#   'Views': '2276',
#   'Likes': '32',
#   'Comments': '4'},
#  {'Title': 'Avvio rapido di Windows, Part6, VELOCIZZARE IL PC',
#   'Published_date': '2013-01-07T18:01:56Z',
#   'Views': '11816',
#   'Likes': '121',
#   'Comments': '22'},
#  {'Title': 'Ottimizzazione Ram Win 7 e XP, Part5, VELOCIZZARE IL PC',
#   'Published_date': '2013-01-01T17:30:31Z',
#   'Views': '16865',
#   'Likes': '185',
#   'Comments': '55'},
#  {'Title': 'Eliminare le toolbar, Part5, Turbo internet',
#   'Published_date': '2013-01-01T17:29:34Z',
#   'Views': '2550',
#   'Likes': '25',
#   'Comments': '9'},
#  {'Title': 'Icone stilose - Iconpackager- parte4 - [BEST GRAFIC PC]',
#   'Published_date': '2012-12-26T15:36:07Z',
#   'Views': '950',
#   'Likes': '24',
#   'Comments': '3'},
#  {'Title': 'Software per smanettoni, Part4, Turbo internet',
#   'Published_date': '2012-12-25T16:41:32Z',
#   'Views': '3247',
#   'Likes': '36',
#   'Comments': '8'},
#  {'Title': '- grafica = + velocità, Part4, VELOCIZZARE IL PC',
#   'Published_date': '2012-12-24T16:47:52Z',
#   'Views': '17464',
#   'Likes': '222',
#   'Comments': '35'},
#  {'Title': 'Diminuire i lag, Part3, Solo Gamer',
#   'Published_date': '2012-12-20T14:22:22Z',
#   'Views': '3219',
#   'Likes': '57',
#   'Comments': '9'},
#  {'Title': 'Software indispensabili, Part3, Turbo internet',
#   'Published_date': '2012-12-18T17:14:33Z',
#   'Views': '21027',
#   'Likes': '191',
#   'Comments': '46'},
#  {'Title': 'Ancora Services.msc, Part3, VELOCIZZARE IL PC',
#   'Published_date': '2012-12-17T17:36:10Z',
#   'Views': '7648',
#   'Likes': '88',
#   'Comments': '17'},
#  {'Title': 'Desktop 3D - Realdesktop - part2 - [BEST GRAFIC PC]',
#   'Published_date': '2012-12-13T15:24:37Z',
#   'Views': '1718',
#   'Likes': '30',
#   'Comments': '7'},
#  {'Title': 'Game booster, Part2, Solo Gamer',
#   'Published_date': '2012-12-12T15:36:07Z',
#   'Views': '4264',
#   'Likes': '97',
#   'Comments': '36'},
#  {'Title': "L'onestà del fornitore, Part2, Turbo internet",
#   'Published_date': '2012-12-11T15:39:43Z',
#   'Views': '8475',
#   'Likes': '154',
#   'Comments': '26'},
#  {'Title': 'Services.msc, Part2, VELOCIZZARE IL PC',
#   'Published_date': '2012-12-10T15:07:14Z',
#   'Views': '15334',
#   'Likes': '181',
#   'Comments': '55'},
#  {'Title': 'Come cambiare la grafica di Windows, Premessa - part1 - [BEST GRAFIC PC]',
#   'Published_date': '2012-12-06T16:06:52Z',
#   'Views': '1997',
#   'Likes': '29',
#   'Comments': '9'},
#  {'Title': 'Consigli per videogiocatori, Premessa, Part1, Solo Gamer',
#   'Published_date': '2012-12-05T19:01:42Z',
#   'Views': '2239',
#   'Likes': '82',
#   'Comments': '11'},
#  {'Title': 'Come velocizzare la connessione internet, Premessa, Part1, Turbo internet',
#   'Published_date': '2012-12-04T15:02:12Z',
#   'Views': '10434',
#   'Likes': '177',
#   'Comments': '15'},
#  {'Title': 'Come velocizzare il computer, Premessa, Part1, VELOCIZZARE IL PC',
#   'Published_date': '2012-12-04T15:01:27Z',
#   'Views': '13028',
#   'Likes': '217',
#   'Comments': '48'},
#  {'Title': 'Velocizzare il pc, Solo gamer, Turbo internet, Best grafic pc',
#   'Published_date': '2012-10-24T13:47:47Z',
#   'Views': '27847',
#   'Likes': '569',
#   'Comments': '164'},
#  {'Title': 'Posso giocare con il mio pc?',
#   'Published_date': '2012-10-15T13:36:57Z',
#   'Views': '3233',
#   'Likes': '65',
#   'Comments': '30'},
#  {'Title': 'Scoprire fotoritocchi',
#   'Published_date': '2012-10-07T16:56:36Z',
#   'Views': '358',
#   'Likes': '16',
#   'Comments': '2'},
#  {'Title': 'Scorciatoie windows',
#   'Published_date': '2012-10-04T11:12:10Z',
#   'Views': '17470',
#   'Likes': '200',
#   'Comments': '18'},
#  {'Title': 'Eliminiamo file per più utenti',
#   'Published_date': '2012-10-01T08:16:44Z',
#   'Views': '265',
#   'Likes': '10',
#   'Comments': '1'},
#  {'Title': 'Disinstallare driver ati - Uninstall driver ati',
#   'Published_date': '2012-09-29T23:23:16Z',
#   'Views': '1869',
#   'Likes': '10',
#   'Comments': '1'},
#  {'Title': 'Disinstallare driver',
#   'Published_date': '2012-09-25T19:48:52Z',
#   'Views': '3275',
#   'Likes': '28',
#   'Comments': '10'},
#  {'Title': 'Dub assembly',
#   'Published_date': '2012-09-20T16:58:53Z',
#   'Views': '787',
#   'Likes': '17',
#   'Comments': '11'},
#  {'Title': 'Template per Guida pc game e xbox 360',
#   'Published_date': '2012-09-17T12:56:13Z',
#   'Views': '382',
#   'Likes': '9',
#   'Comments': '1'},
#  {'Title': 'Il ritorno',
#   'Published_date': '2012-09-17T10:26:29Z',
#   'Views': '864',
#   'Likes': '33',
#   'Comments': '6'},
#  {'Title': 'Soluzione desktop DOCK BAR nexsus e gadget',
#   'Published_date': '2011-12-07T19:48:24Z',
#   'Views': '3971',
#   'Likes': '46',
#   'Comments': '13'},
#  {'Title': 'Assemblare non è per novellini',
#   'Published_date': '2011-08-25T22:59:45Z',
#   'Views': '13922',
#   'Likes': '133',
#   'Comments': '60'},
#  {'Title': 'Come pagare il dominio con aruba',
#   'Published_date': '2011-08-03T06:26:17Z',
#   'Views': '3951',
#   'Likes': '11',
#   'Comments': '2'},
#  {'Title': 'Risolvere problema pagina bianca artforms',
#   'Published_date': '2011-07-04T04:35:18Z',
#   'Views': '765',
#   'Likes': '4',
#   'Comments': '0'},
#  {'Title': 'Come usare torrent - Tutorial',
#   'Published_date': '2011-03-01T07:42:43Z',
#   'Views': '21040',
#   'Likes': '38',
#   'Comments': '6'},
#  {'Title': 'perche mandare messaggi offline?',
#   'Published_date': '2010-12-23T18:22:43Z',
#   'Views': '514',
#   'Likes': '7',
#   'Comments': '0'},
#  {'Title': 'Cacciare Bonjour dnsresponder',
#   'Published_date': '2010-12-06T16:08:38Z',
#   'Views': '556',
#   'Likes': '12',
#   'Comments': '0'},
#  {'Title': 'Ridimensionare foto online',
#   'Published_date': '2010-12-04T03:20:30Z',
#   'Views': '347',
#   'Likes': '4',
#   'Comments': '0'},
#  {'Title': 'I Gigabyte come i Cavalli delle macchine',
#   'Published_date': '2010-11-22T03:32:32Z',
#   'Views': '1263',
#   'Likes': '18',
#   'Comments': '2'},
#  {'Title': 'Scelta del miglior antivirus',
#   'Published_date': '2010-11-22T03:32:22Z',
#   'Views': '9334',
#   'Likes': '73',
#   'Comments': '12'},
#  {'Title': 'Quanto costa un PC?',
#   'Published_date': '2010-11-22T02:33:55Z',
#   'Views': '5479',
#   'Likes': '59',
#   'Comments': '4'},
#  {'Title': 'Persone e PC',
#   'Published_date': '2010-11-22T01:44:34Z',
#   'Views': '1940',
#   'Likes': '43',
#   'Comments': '13'}]
